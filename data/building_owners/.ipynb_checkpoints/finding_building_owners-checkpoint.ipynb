# %% [markdown]
# # Who Owns the Large Buildings in Seattle?
#
# ## Problem
#
# The GHGE dataset does not include buildings' owners. Scraping the eRealProperty website for building owners has two limitations:
#
# 1. The data quality is poor and many buildings don't have an owner listed.
# 1. Many corporations with multiple properties set up a separate LLC for each building. There is no straightforward way to trace a child corporation to its parent coroporation. This obfuscates the portfolio size of each company.

# %%
import pandas as pd
import numpy as np
import requests
from fuzzywuzzy import fuzz
import json

# %% [markdown]
# 1. Find business record
# 1. Find business' governors
# 1. Find other businesses with those governors
# 1. Match the businesses

# %%
# Find business record
# first need to search and determine business ID

search_for_business_url = 'https://cfda.sos.wa.gov/api/BusinessSearch/GetBusinessSearchList'

def get_business_search_payload(business_name):
    return {
        'Type': 'BusinessName',
        'SearchType': 'BusinessName',
        'SearchEntityName': business_name,
        'SortType': 'ASC',
        'SortBy': 'Entity Name',
        'SearchValue': business_name,
        'SearchCriteria': 'Contains',
        'IsSearch': 'true',
        'PageID': 1,
        'PageCount': 25,
    }

def get_business_search_results(business_name):
    r = requests.post(search_for_business_url, get_business_search_payload(business_name))
    return json.loads(r.text)

# %%
test_name = 'TMUD GSL LLC'

test_search_req = get_business_search_results('TMUD GSL LLC')
test_search_req
# Out:
# [{'IsAvailable': False,
#   'PrincipalOffice': {'PrincipalID': 0,
#    'SequenceNo': 0,
#    'FirstName': None,
#    'LastName': None,
#    'FullName': None,
#    'Title': None,
#    'Name': None,
#    'MiddleName': None,
#    'PhoneNumber': None,
#    'EmailAddress': None,
#    'TypeID': None,
#    'PrincipalBaseType': None,
#    'PrincipalMailingAddress': {'Attention': None,
#     'NotificationAttention': None,
#     'CorrespondenceEmailAddress': None,
#     'ConsolidationCorrespondenceEmailAddress': None,
#     'ZipExtension': None,
#     'AddressEntityType': None,
#     'IsAddressSame': False,
#     'isUserNonCommercialRegisteredAgent': False,
#     'baseEntity': {'FilerID': 0,
#      'UserID': 0,
#      'CreatedBy': 0,
#      'IPAddress': None,
#      'ModifiedBy': 0,
#      'ModifiedIPAddress': None},
#     'IsInvalidState': False,
#     'IsAgentInWA': None,
#     'isRAStreetAddressValid': False,
#     'IsAddressReturnedMail': False,
#     'FullAddress': 'BELLEVUE, WA, USA, 4408, 98004',
#     'ID': 0,
#     'StreetAddress1': 'BELLEVUE',
#     'StreetAddress2': 'WA',
#     'City': 'USA',
#     'State': '',
#     'OtherState': '',
#     'Country': '98004',
#     'Zip5': '',
#     'Zip4': '',
#     'PostalCode': '4408',
#     'County': None,
#     'CountyName': None,
#     'CountryName': '98004'},
#    'PrincipalStreetAddress': {'Attention': None,
#     'NotificationAttention': None,
#     'CorrespondenceEmailAddress': None,
#     'ConsolidationCorrespondenceEmailAddress': None,
#     'ZipExtension': None,
#     'AddressEntityType': None,
#     'IsAddressSame': False,
#     'isUserNonCommercialRegisteredAgent': False,
#     'baseEntity': {'FilerID': 0,
#      'UserID': 0,
#      'CreatedBy': 0,
#      'IPAddress': None,
#      'ModifiedBy': 0,
#      'ModifiedIPAddress': None},
#     'IsInvalidState': False,
#     'IsAgentInWA': None,
#     'isRAStreetAddressValid': False,
#     'IsAddressReturnedMail': False,
#     'FullAddress': '11010 NE 8TH ST STE 465, BELLEVUE, WA, 98004-4408, UNITED STATES',
#     'ID': 0,
#     'StreetAddress1': '11010 NE 8TH ST STE 465',
#     'StreetAddress2': '',
#     'City': 'BELLEVUE',
#     'State': 'WA',
#     'OtherState': '',
#     'Country': 'USA',
#     'Zip5': '98004',
#     'Zip4': '4408',
#     'PostalCode': '',
#     'County': None,
#     'CountyName': None,
#     'CountryName': 'UNITED STATES'},
#    'IsSameAsMailingAddress': False,
#    'IsSameAsAgentAddress': False,
#    'BusinessID': 0,
#    'Status': None,
#    'MemberOrManager': 0,
#    'IsPrincipalOfficeNotInWa': False,
#    'IsFormation': False,
#    'IsNotRequired': False,
#    'IsACP': False,
#    'ParticipantNumber': None,
#    'IsForNonProfitAmendment': False,
#    'IsOldDataExist': True,
#    'FilerID': 0,
#    'UserID': 0,
#    'CreatedBy': 0,
#    'IPAddress': None,
#    'ModifiedBy': 0,
#    'ModifiedIPAddress': None},
#   'PrincipalOfficeInWA': None,
#   'Agent': {'Type': None,
#    'AgentID': 0,
#    'EntityName': None,
#    'OrganizationName': None,
#    'FirstName': None,
#    'LastName': None,
#    'IsNonCommercial': False,
#    'EmailAddress': None,
#    'AgentTypeID': 0,
#    'StreetAddress': {'Attention': None,
#     'NotificationAttention': None,
#     'CorrespondenceEmailAddress': None,
#     'ConsolidationCorrespondenceEmailAddress': None,
#     'ZipExtension': None,
#     'AddressEntityType': None,
#     'IsAddressSame': False,
#     'isUserNonCommercialRegisteredAgent': False,
#     'baseEntity': {'FilerID': 0,
#      'UserID': 0,
#      'CreatedBy': 0,
#      'IPAddress': None,
#      'ModifiedBy': 0,
#      'ModifiedIPAddress': None},
#     'IsInvalidState': False,
#     'IsAgentInWA': None,
#     'isRAStreetAddressValid': False,
#     'IsAddressReturnedMail': False,
#     'FullAddress': '',
#     'ID': 0,
#     'StreetAddress1': None,
#     'StreetAddress2': None,
#     'City': None,
#     'State': None,
#     'OtherState': None,
#     'Country': None,
#     'Zip5': None,
#     'Zip4': None,
#     'PostalCode': None,
#     'County': None,
#     'CountyName': None,
#     'CountryName': ''},
#    'MailingAddress': {'Attention': None,
#     'NotificationAttention': None,
#     'CorrespondenceEmailAddress': None,
#     'ConsolidationCorrespondenceEmailAddress': None,
#     'ZipExtension': None,
#     'AddressEntityType': None,
#     'IsAddressSame': False,
#     'isUserNonCommercialRegisteredAgent': False,
#     'baseEntity': {'FilerID': 0,
#      'UserID': 0,
#      'CreatedBy': 0,
#      'IPAddress': None,
#      'ModifiedBy': 0,
#      'ModifiedIPAddress': None},
#     'IsInvalidState': False,
#     'IsAgentInWA': None,
#     'isRAStreetAddressValid': False,
#     'IsAddressReturnedMail': False,
#     'FullAddress': '',
#     'ID': 0,
#     'StreetAddress1': None,
#     'StreetAddress2': None,
#     'City': None,
#     'State': None,
#     'OtherState': None,
#     'Country': None,
#     'Zip5': None,
#     'Zip4': None,
#     'PostalCode': None,
#     'County': None,
#     'CountyName': None,
#     'CountryName': ''},
#    'IsUserRegisteredAgent': False,
#    'PhoneNumber': None,
#    'IsRegisteredAgentConsent': False,
#    'Title': None,
#    'IsSameAsMailingAddress': False,
#    'CreatedBy': None,
#    'AgentCreatdDate': None,
#    'AgentCreatdIP': None,
#    'IsNewAgent': False,
#    'TotalCount': 0,
#    'IsAgentConsentShow': False,
#    'IsAgentChange': False,
#    'IsAgentFormation': False,
#    'OfficeOrPosition': '',
#    'BusinessIDForRA': 0,
#    'BusinessAgentAddressID': 0,
#    'BusinessAgentMailingAddressID': 0,
#    'IsAgentEdit': False,
#    'IsAgentAltered': False,
#    'IsOnlineAgent': False,
#    'Criteria': None,
#    'AgentStreet1': None,
#    'AgentStreet2': None,
#    'City': None,
#    'State': None,
#    'OtherState': None,
#    'PostalCode': None,
#    'Country': None,
#    'Zip4': None,
#    'Zip5': None,
#    'BusinessTypeID': 0,
#    'BusinessType': None,
#    'Jurisdiction': 0,
#    'JurisdictionDesc': None,
#    'JurisdictionState': 0,
#    'JurisdictionCountry': 0,
#    'JurisdictionStateDesc': None,
#    'JurisdictionCountryDesc': None,
#    'JurisdictionCategory': None,
#    'IsCRARegistration': False,
#    'IsCRAAttestation': False,
#    'IsCRANotification': False,
#    'IsCRAStatementofChanged': False,
#    'IsRepresentedAttestation': False,
#    'OldEntityName': None,
#    'OldFirstName': None,
#    'OldLastName': None,
#    'isStreetStateMustbeinWA': False,
#    'isMailingStateMustbeinWA': False,
#    'isRAAddressValid': False,
#    'IsAmendmentAgentInfoChange': False,
#    'IsRAOfficeorPositionSearch': False,
#    'FullName': '',
#    'AgentType': None,
#    'IsACP': False,
#    'ParticipantNumber': None},
#   'PrincipalsList': None,
#   'PrincipalName': None,
#   'SearchCriteria': None,
#   'SearchType': None,
#   'SearchTypeText': None,
#   'SearchValue': None,
#   'SearchEntityName': None,
#   'StartDateOfIncorporation': '0001-01-01T00:00:00',
#   'EndDateOfIncorporation': '0001-01-01T00:00:00',
#   'ExpirationDate': '0001-01-01T00:00:00',
#   'Criteria': {'ID': None,
#    'MulitipleIDs': None,
#    'Type': 'BusinessName',
#    'BusinessType': None,
#    'TypeID': 0,
#    'PageID': 1,
#    'PageCount': 25,
#    'TotalRowCount': 3,
#    'SearchValue': '%TMUD%GSL%',
#    'SearchEntityName': 'TMUDGSL%',
#    'IsSearch': True,
#    'SearchCriteria': 'Contains',
#    'GrandTotal': 0.0,
#    'BusinessStatusID': 0,
#    'BusinessTypeId': None,
#    'FilingTypeId': None,
#    'UserId': 0,
#    'AgentName': None,
#    'PrincipalName': None,
#    'AgentAddress': None,
#    'PrincipalAddress': None,
#    'StartDateOfIncorporation': None,
#    'EndDateOfIncorporation': None,
#    'ExpirationDate': None,
#    'Fields': None,
#    'IsOnline': False,
#    'IsInhouse': False,
#    'SearchType': 'BusinessName',
#    'AgentId': 0,
#    'DueDate': '0001-01-01T00:00:00',
#    'ModifiedDate': '0001-01-01T00:00:00',
#    'FilerId': 0,
#    'isSuccess': False,
#    'FilingNumber': 0,
#    'PercentToProgramServices': None,
#    'UBINumber': None,
#    'FEINNo': None,
#    'RegistrationNumber': 0,
#    'KeyWordSearch': None,
#    'EntityName': None,
#    'CharityId': 0,
#    'FundraiserId': 0,
#    'TrustId': 0,
#    'Address1': None,
#    'Address2': None,
#    'City': None,
#    'County': 0,
#    'State': None,
#    'Zip5': None,
#    'Zip4': None,
#    'Zip': None,
#    'Officers': None,
#    'Address': None,
#    'Status': None,
#    'OrganizationType': None,
#    'RenewalDate': '0001-01-01T00:00:00',
#    'TaxExemptStatus': 0,
#    'Hotlist': None,
#    'ReferredToAG': None,
#    'Notifications': None,
#    'DateRangeStartDate': '0001-01-01T00:00:00',
#    'DateRangeEndDate': '0001-01-01T00:00:00',
#    'Export': 0,
#    'InquiryStatus': 0,
#    'TrasactionCategory': None,
#    'isOptionalRegistration': False,
#    'AdvanceIsOptionalRegistration': None,
#    'InquiryStatusId': None,
#    'SortType': 'ASC',
#    'SortBy': 'Entity Name',
#    'CFTType': None,
#    'TrademarkGoodsID': None,
#    'TrademarkServicesID': None,
#    'TrademarkText': None,
#    'TrademarkOwnerName': None,
#    'TrademarkRegistrationNo': None,
#    'DocumentTypeID': 0,
#    'DocumentID': 0,
#    'IsAdvancedSearch': False,
#    'IsHostHomeSearch': None,
#    'IsPublicBenefitNonProfitSearch': None,
#    'IsCharitableNonProfitSearch': None,
#    'IsGrossRevenueNonProfitSearch': None,
#    'IsHasMembersSearch': None,
#    'IsHasFEINSearch': None,
#    'FEINNoSearch': None,
#    'IsCharitableNonProfit': False,
#    'CFTBusinessList': None},
#   'GrangeAddress': None,
#   'MeetingPlace': None,
#   'IsOrgBusinessName': False,
#   'CheckBusinessName': None,
#   'PlusOrMinusOrder': 0,
#   'FiltereRecordId': 0,
#   'ModifiedDate': '0001-01-01T00:00:00',
#   'DissolutionDays': 0,
#   'ID': 0,
#   'isInhouse': False,
#   'FeeList': None,
#   'UBIStatus': None,
#   'IsUbiNumber': False,
#   'NewUBINumber': None,
#   'IsShowAdvanceSearch': False,
#   'EntityName': None,
#   'Status': None,
#   'Type': None,
#   'IsHostHomeSearch': None,
#   'IsPublicBenefitNonProfitSearch': None,
#   'IsCharitableNonProfitSearch': None,
#   'IsGrossRevenueNonProfitSearch': None,
#   'IsHasMembersSearch': None,
#   'IsHasFEINSearch': None,
#   'FEINNoSearch': None,
#   'IsHostHome': None,
#   'IsPublicBenefitNonProfit': None,
#   'IsCharitableNonProfit': None,
#   'IsGrossRevenueNonProfit': None,
#   'IsHasMembers': None,
#   'IsHasFEIN': None,
#   'EntityTypesWithScreens': {},
#   'AllScreenParts': {},
#   'OnlineReportPrincipalList': None,
#   'OnlineUploadDocumentsList': [],
#   'UploadDocumentsList': [],
#   'PrincipalMemberList': [],
#   'CorrespondenceAddress': {'Attention': None,
#    'NotificationAttention': None,
#    'CorrespondenceEmailAddress': None,
#    'ConsolidationCorrespondenceEmailAddress': None,
#    'ZipExtension': None,
#    'AddressEntityType': None,
#    'IsAddressSame': False,
#    'isUserNonCommercialRegisteredAgent': False,
#    'baseEntity': {'FilerID': 0,
#     'UserID': 0,
#     'CreatedBy': 0,
#     'IPAddress': None,
#     'ModifiedBy': 0,
#     'ModifiedIPAddress': None},
#    'IsInvalidState': False,
#    'IsAgentInWA': None,
#    'isRAStreetAddressValid': False,
#    'IsAddressReturnedMail': False,
#    'FullAddress': '',
#    'ID': 0,
#    'StreetAddress1': None,
#    'StreetAddress2': None,
#    'City': None,
#    'State': None,
#    'OtherState': None,
#    'Country': None,
#    'Zip5': None,
#    'Zip4': None,
#    'PostalCode': None,
#    'County': None,
#    'CountyName': None,
#    'CountryName': ''},
#   'OnlineReportAgent': {'Type': None,
#    'AgentID': 0,
#    'EntityName': None,
#    'OrganizationName': None,
#    'FirstName': None,
#    'LastName': None,
#    'IsNonCommercial': False,
#    'EmailAddress': None,
#    'AgentTypeID': 0,
#    'StreetAddress': {'Attention': None,
#     'NotificationAttention': None,
#     'CorrespondenceEmailAddress': None,
#     'ConsolidationCorrespondenceEmailAddress': None,
#     'ZipExtension': None,
#     'AddressEntityType': None,
#     'IsAddressSame': False,
#     'isUserNonCommercialRegisteredAgent': False,
#     'baseEntity': {'FilerID': 0,
#      'UserID': 0,
#      'CreatedBy': 0,
#      'IPAddress': None,
#      'ModifiedBy': 0,
#      'ModifiedIPAddress': None},
#     'IsInvalidState': False,
#     'IsAgentInWA': None,
#     'isRAStreetAddressValid': False,
#     'IsAddressReturnedMail': False,
#     'FullAddress': '',
#     'ID': 0,
#     'StreetAddress1': None,
#     'StreetAddress2': None,
#     'City': None,
#     'State': None,
#     'OtherState': None,
#     'Country': None,
#     'Zip5': None,
#     'Zip4': None,
#     'PostalCode': None,
#     'County': None,
#     'CountyName': None,
#     'CountryName': ''},
#    'MailingAddress': {'Attention': None,
#     'NotificationAttention': None,
#     'CorrespondenceEmailAddress': None,
#     'ConsolidationCorrespondenceEmailAddress': None,
#     'ZipExtension': None,
#     'AddressEntityType': None,
#     'IsAddressSame': False,
#     'isUserNonCommercialRegisteredAgent': False,
#     'baseEntity': {'FilerID': 0,
#      'UserID': 0,
#      'CreatedBy': 0,
#      'IPAddress': None,
#      'ModifiedBy': 0,
#      'ModifiedIPAddress': None},
#     'IsInvalidState': False,
#     'IsAgentInWA': None,
#     'isRAStreetAddressValid': False,
#     'IsAddressReturnedMail': False,
#     'FullAddress': '',
#     'ID': 0,
#     'StreetAddress1': None,
#     'StreetAddress2': None,
#     'City': None,
#     'State': None,
#     'OtherState': None,
#     'Country': None,
#     'Zip5': None,
#     'Zip4': None,
#     'PostalCode': None,
#     'County': None,
#     'CountyName': None,
#     'CountryName': ''},
#    'IsUserRegisteredAgent': False,
#    'PhoneNumber': None,
#    'IsRegisteredAgentConsent': False,
#    'Title': None,
#    'IsSameAsMailingAddress': False,
#    'CreatedBy': None,
#    'AgentCreatdDate': None,
#    'AgentCreatdIP': None,
#    'IsNewAgent': False,
#    'TotalCount': 0,
#    'IsAgentConsentShow': False,
#    'IsAgentChange': False,
#    'IsAgentFormation': False,
#    'OfficeOrPosition': None,
#    'BusinessIDForRA': 0,
#    'BusinessAgentAddressID': 0,
#    'BusinessAgentMailingAddressID': 0,
#    'IsAgentEdit': False,
#    'IsAgentAltered': False,
#    'IsOnlineAgent': False,
#    'Criteria': None,
#    'AgentStreet1': None,
#    'AgentStreet2': None,
#    'City': None,
#    'State': None,
#    'OtherState': None,
#    'PostalCode': None,
#    'Country': None,
#    'Zip4': None,
#    'Zip5': None,
#    'BusinessTypeID': 0,
#    'BusinessType': None,
#    'Jurisdiction': 0,
#    'JurisdictionDesc': None,
#    'JurisdictionState': 0,
#    'JurisdictionCountry': 0,
#    'JurisdictionStateDesc': None,
#    'JurisdictionCountryDesc': None,
#    'JurisdictionCategory': None,
#    'IsCRARegistration': False,
#    'IsCRAAttestation': False,
#    'IsCRANotification': False,
#    'IsCRAStatementofChanged': False,
#    'IsRepresentedAttestation': False,
#    'OldEntityName': None,
#    'OldFirstName': None,
#    'OldLastName': None,
#    'isStreetStateMustbeinWA': False,
#    'isMailingStateMustbeinWA': False,
#    'isRAAddressValid': False,
#    'IsAmendmentAgentInfoChange': False,
#    'IsRAOfficeorPositionSearch': False,
#    'FullName': '',
#    'AgentType': None,
#    'IsACP': False,
#    'ParticipantNumber': None},
#   'TrademarkOwnerAgent': {'Type': None,
#    'AgentID': 0,
#    'EntityName': None,
#    'OrganizationName': None,
#    'FirstName': None,
#    'LastName': None,
#    'IsNonCommercial': False,
#    'EmailAddress': None,
#    'AgentTypeID': 0,
#    'StreetAddress': {'Attention': None,
#     'NotificationAttention': None,
#     'CorrespondenceEmailAddress': None,
#     'ConsolidationCorrespondenceEmailAddress': None,
#     'ZipExtension': None,
#     'AddressEntityType': None,
#     'IsAddressSame': False,
#     'isUserNonCommercialRegisteredAgent': False,
#     'baseEntity': {'FilerID': 0,
#      'UserID': 0,
#      'CreatedBy': 0,
#      'IPAddress': None,
#      'ModifiedBy': 0,
#      'ModifiedIPAddress': None},
#     'IsInvalidState': False,
#     'IsAgentInWA': None,
#     'isRAStreetAddressValid': False,
#     'IsAddressReturnedMail': False,
#     'FullAddress': '',
#     'ID': 0,
#     'StreetAddress1': None,
#     'StreetAddress2': None,
#     'City': None,
#     'State': None,
#     'OtherState': None,
#     'Country': None,
#     'Zip5': None,
#     'Zip4': None,
#     'PostalCode': None,
#     'County': None,
#     'CountyName': None,
#     'CountryName': ''},
#    'MailingAddress': {'Attention': None,
#     'NotificationAttention': None,
#     'CorrespondenceEmailAddress': None,
#     'ConsolidationCorrespondenceEmailAddress': None,
#     'ZipExtension': None,
#     'AddressEntityType': None,
#     'IsAddressSame': False,
#     'isUserNonCommercialRegisteredAgent': False,
#     'baseEntity': {'FilerID': 0,
#      'UserID': 0,
#      'CreatedBy': 0,
#      'IPAddress': None,
#      'ModifiedBy': 0,
#      'ModifiedIPAddress': None},
#     'IsInvalidState': False,
#     'IsAgentInWA': None,
#     'isRAStreetAddressValid': False,
#     'IsAddressReturnedMail': False,
#     'FullAddress': '',
#     'ID': 0,
#     'StreetAddress1': None,
#     'StreetAddress2': None,
#     'City': None,
#     'State': None,
#     'OtherState': None,
#     'Country': None,
#     'Zip5': None,
#     'Zip4': None,
#     'PostalCode': None,
#     'County': None,
#     'CountyName': None,
#     'CountryName': ''},
#    'IsUserRegisteredAgent': False,
#    'PhoneNumber': None,
#    'IsRegisteredAgentConsent': False,
#    'Title': None,
#    'IsSameAsMailingAddress': False,
#    'CreatedBy': None,
#    'AgentCreatdDate': None,
#    'AgentCreatdIP': None,
#    'IsNewAgent': False,
#    'TotalCount': 0,
#    'IsAgentConsentShow': False,
#    'IsAgentChange': False,
#    'IsAgentFormation': False,
#    'OfficeOrPosition': None,
#    'BusinessIDForRA': 0,
#    'BusinessAgentAddressID': 0,
#    'BusinessAgentMailingAddressID': 0,
#    'IsAgentEdit': False,
#    'IsAgentAltered': False,
#    'IsOnlineAgent': False,
#    'Criteria': None,
#    'AgentStreet1': None,
#    'AgentStreet2': None,
#    'City': None,
#    'State': None,
#    'OtherState': None,
#    'PostalCode': None,
#    'Country': None,
#    'Zip4': None,
#    'Zip5': None,
#    'BusinessTypeID': 0,
#    'BusinessType': None,
#    'Jurisdiction': 0,
#    'JurisdictionDesc': None,
#    'JurisdictionState': 0,
#    'JurisdictionCountry': 0,
#    'JurisdictionStateDesc': None,
#    'JurisdictionCountryDesc': None,
#    'JurisdictionCategory': None,
#    'IsCRARegistration': False,
#    'IsCRAAttestation': False,
#    'IsCRANotification': False,
#    'IsCRAStatementofChanged': False,
#    'IsRepresentedAttestation': False,
#    'OldEntityName': None,
#    'OldFirstName': None,
#    'OldLastName': None,
#    'isStreetStateMustbeinWA': False,
#    'isMailingStateMustbeinWA': False,
#    'isRAAddressValid': False,
#    'IsAmendmentAgentInfoChange': False,
#    'IsRAOfficeorPositionSearch': False,
#    'FullName': '',
#    'AgentType': None,
#    'IsACP': False,
#    'ParticipantNumber': None},
#   'OnlineReportAuthorizedPerson': {'AuthorizedPersonFirstName': None,
#    'AuthorizedPersonLastName': None,
#    'AuthorizedPersonTitle': None,
#    'AuthorizedPersonEntityName': None,
#    'IsAccepted': False,
#    'DocUnderPenalities': None,
#    'DocIsSigned': False,
#    'IsRAorTrusteeCoverSheetSigned': False,
#    'IsTrustreeSignedTrustAgreement': False,
#    'PersonType': None,
#    'IsRequired': False,
#    'AuthorizerName': None,
#    'ErrorMsgs': None,
#    'InhouseReviewHTML': None,
#    'InhouseInitialReportReviewHTML': None},
#   'OnlineReportBusinessTransaction': None,
#   'ARDueDate': '0001-01-01T00:00:00',
#   'createdDate': '0001-01-01T00:00:00',
#   'DateBeganDoingBusinessInWA': '0001-01-01T00:00:00',
#   'DateOfAdoption': '0001-01-01T00:00:00',
#   'DateOfFormationInHomeJurisdiction': '0001-01-01T00:00:00',
#   'DateOfIncorporation': '0001-01-01T00:00:00',
#   'DissolvedDate': '0001-01-01T00:00:00',
#   'EffectiveDate': '0001-01-01T00:00:00',
#   'ExpirationDateReview': '0001-01-01T00:00:00',
#   'FilingDate': '0001-01-01T00:00:00',
#   'NextARDueDate': '0001-01-01T00:00:00',
#   'PeriodofDurationDate': '0001-01-01T00:00:00',
#   'RAExpiredDate': '0001-01-01T00:00:00',
#   'ReinstatementDissolutionEndDate': '0001-01-01T00:00:00',
#   'RenewalDate': '0001-01-01T00:00:00',
#   'RequalificationTerminationEndDate': '0001-01-01T00:00:00',
#   'DurationExpireDate': None,
#   'InActiveDate': None,
#   'LastARFiledDate': '0001-01-01T00:00:00',
#   'NameReservationExpireDate': None,
#   'PeriodofDurationDateReview': None,
#   'OnlineReportNatureOfBusiness': None,
#   'OnlineCartEntity': None,
#   'BusinessInfoPrincipalOffice': {'PrincipalID': 0,
#    'SequenceNo': 0,
#    'FirstName': None,
#    'LastName': None,
#    'FullName': None,
#    'Title': None,
#    'Name': None,
#    'MiddleName': None,
#    'PhoneNumber': None,
#    'EmailAddress': None,
#    'TypeID': None,
#    'PrincipalBaseType': None,
#    'PrincipalMailingAddress': {'Attention': None,
#     'NotificationAttention': None,
#     'CorrespondenceEmailAddress': None,
#     'ConsolidationCorrespondenceEmailAddress': None,
#     'ZipExtension': None,
#     'AddressEntityType': None,
#     'IsAddressSame': False,
#     'isUserNonCommercialRegisteredAgent': False,
#     'baseEntity': {'FilerID': 0,
#      'UserID': 0,
#      'CreatedBy': 0,
#      'IPAddress': None,
#      'ModifiedBy': 0,
#      'ModifiedIPAddress': None},
#     'IsInvalidState': False,
#     'IsAgentInWA': None,
#     'isRAStreetAddressValid': False,
#     'IsAddressReturnedMail': False,
#     'FullAddress': '',
#     'ID': 0,
#     'StreetAddress1': None,
#     'StreetAddress2': None,
#     'City': None,
#     'State': None,
#     'OtherState': None,
#     'Country': None,
#     'Zip5': None,
#     'Zip4': None,
#     'PostalCode': None,
#     'County': None,
#     'CountyName': None,
#     'CountryName': ''},
#    'PrincipalStreetAddress': {'Attention': None,
#     'NotificationAttention': None,
#     'CorrespondenceEmailAddress': None,
#     'ConsolidationCorrespondenceEmailAddress': None,
#     'ZipExtension': None,
#     'AddressEntityType': None,
#     'IsAddressSame': False,
#     'isUserNonCommercialRegisteredAgent': False,
#     'baseEntity': {'FilerID': 0,
#      'UserID': 0,
#      'CreatedBy': 0,
#      'IPAddress': None,
#      'ModifiedBy': 0,
#      'ModifiedIPAddress': None},
#     'IsInvalidState': False,
#     'IsAgentInWA': None,
#     'isRAStreetAddressValid': False,
#     'IsAddressReturnedMail': False,
#     'FullAddress': '',
#     'ID': 0,
#     'StreetAddress1': None,
#     'StreetAddress2': None,
#     'City': None,
#     'State': None,
#     'OtherState': None,
#     'Country': None,
#     'Zip5': None,
#     'Zip4': None,
#     'PostalCode': None,
#     'County': None,
#     'CountyName': None,
#     'CountryName': ''},
#    'IsSameAsMailingAddress': False,
#    'IsSameAsAgentAddress': False,
#    'BusinessID': 0,
#    'Status': None,
#    'MemberOrManager': 0,
#    'IsPrincipalOfficeNotInWa': False,
#    'IsFormation': False,
#    'IsNotRequired': False,
#    'IsACP': False,
#    'ParticipantNumber': None,
#    'IsForNonProfitAmendment': False,
#    'IsOldDataExist': False,
#    'FilerID': 0,
#    'UserID': 0,
#    'CreatedBy': 0,
#    'IPAddress': None,
#    'ModifiedBy': 0,
#    'ModifiedIPAddress': None},
#   'BusinessInfoPrincipalOfficeInWA': {'PrincipalID': 0,
#    'SequenceNo': 0,
#    'FirstName': None,
#    'LastName': None,
#    'FullName': None,
#    'Title': None,
#    'Name': None,
#    'MiddleName': None,
#    'PhoneNumber': None,
#    'EmailAddress': None,
#    'TypeID': None,
#    'PrincipalBaseType': None,
#    'PrincipalMailingAddress': {'Attention': None,
#     'NotificationAttention': None,
#     'CorrespondenceEmailAddress': None,
#     'ConsolidationCorrespondenceEmailAddress': None,
#     'ZipExtension': None,
#     'AddressEntityType': None,
#     'IsAddressSame': False,
#     'isUserNonCommercialRegisteredAgent': False,
#     'baseEntity': {'FilerID': 0,
#      'UserID': 0,
#      'CreatedBy': 0,
#      'IPAddress': None,
#      'ModifiedBy': 0,
#      'ModifiedIPAddress': None},
#     'IsInvalidState': False,
#     'IsAgentInWA': None,
#     'isRAStreetAddressValid': False,
#     'IsAddressReturnedMail': False,
#     'FullAddress': '',
#     'ID': 0,
#     'StreetAddress1': None,
#     'StreetAddress2': None,
#     'City': None,
#     'State': None,
#     'OtherState': None,
#     'Country': None,
#     'Zip5': None,
#     'Zip4': None,
#     'PostalCode': None,
#     'County': None,
#     'CountyName': None,
#     'CountryName': ''},
#    'PrincipalStreetAddress': {'Attention': None,
#     'NotificationAttention': None,
#     'CorrespondenceEmailAddress': None,
#     'ConsolidationCorrespondenceEmailAddress': None,
#     'ZipExtension': None,
#     'AddressEntityType': None,
#     'IsAddressSame': False,
#     'isUserNonCommercialRegisteredAgent': False,
#     'baseEntity': {'FilerID': 0,
#      'UserID': 0,
#      'CreatedBy': 0,
#      'IPAddress': None,
#      'ModifiedBy': 0,
#      'ModifiedIPAddress': None},
#     'IsInvalidState': False,
#     'IsAgentInWA': None,
#     'isRAStreetAddressValid': False,
#     'IsAddressReturnedMail': False,
#     'FullAddress': '',
#     'ID': 0,
#     'StreetAddress1': None,
#     'StreetAddress2': None,
#     'City': None,
#     'State': None,
#     'OtherState': None,
#     'Country': None,
#     'Zip5': None,
#     'Zip4': None,
#     'PostalCode': None,
#     'County': None,
#     'CountyName': None,
#     'CountryName': ''},
#    'IsSameAsMailingAddress': False,
#    'IsSameAsAgentAddress': False,
#    'BusinessID': 0,
#    'Status': None,
#    'MemberOrManager': 0,
#    'IsPrincipalOfficeNotInWa': False,
#    'IsFormation': False,
#    'IsNotRequired': False,
#    'IsACP': False,
#    'ParticipantNumber': None,
#    'IsForNonProfitAmendment': False,
#    'IsOldDataExist': False,
#    'FilerID': 0,
#    'UserID': 0,
#    'CreatedBy': 0,
#    'IPAddress': None,
#    'ModifiedBy': 0,
#    'ModifiedIPAddress': None},
#   'OnlineReportPrincipalOffice': {'PrincipalID': 0,
#    'SequenceNo': 0,
#    'FirstName': None,
#    'LastName': None,
#    'FullName': None,
#    'Title': None,
#    'Name': None,
#    'MiddleName': None,
#    'PhoneNumber': None,
#    'EmailAddress': None,
#    'TypeID': None,
#    'PrincipalBaseType': None,
#    'PrincipalMailingAddress': {'Attention': None,
#     'NotificationAttention': None,
#     'CorrespondenceEmailAddress': None,
#     'ConsolidationCorrespondenceEmailAddress': None,
#     'ZipExtension': None,
#     'AddressEntityType': None,
#     'IsAddressSame': False,
#     'isUserNonCommercialRegisteredAgent': False,
#     'baseEntity': {'FilerID': 0,
#      'UserID': 0,
#      'CreatedBy': 0,
#      'IPAddress': None,
#      'ModifiedBy': 0,
#      'ModifiedIPAddress': None},
#     'IsInvalidState': False,
#     'IsAgentInWA': None,
#     'isRAStreetAddressValid': False,
#     'IsAddressReturnedMail': False,
#     'FullAddress': '',
#     'ID': 0,
#     'StreetAddress1': None,
#     'StreetAddress2': None,
#     'City': None,
#     'State': None,
#     'OtherState': None,
#     'Country': None,
#     'Zip5': None,
#     'Zip4': None,
#     'PostalCode': None,
#     'County': None,
#     'CountyName': None,
#     'CountryName': ''},
#    'PrincipalStreetAddress': {'Attention': None,
#     'NotificationAttention': None,
#     'CorrespondenceEmailAddress': None,
#     'ConsolidationCorrespondenceEmailAddress': None,
#     'ZipExtension': None,
#     'AddressEntityType': None,
#     'IsAddressSame': False,
#     'isUserNonCommercialRegisteredAgent': False,
#     'baseEntity': {'FilerID': 0,
#      'UserID': 0,
#      'CreatedBy': 0,
#      'IPAddress': None,
#      'ModifiedBy': 0,
#      'ModifiedIPAddress': None},
#     'IsInvalidState': False,
#     'IsAgentInWA': None,
#     'isRAStreetAddressValid': False,
#     'IsAddressReturnedMail': False,
#     'FullAddress': '',
#     'ID': 0,
#     'StreetAddress1': None,
#     'StreetAddress2': None,
#     'City': None,
#     'State': None,
#     'OtherState': None,
#     'Country': None,
#     'Zip5': None,
#     'Zip4': None,
#     'PostalCode': None,
#     'County': None,
#     'CountyName': None,
#     'CountryName': ''},
#    'IsSameAsMailingAddress': False,
#    'IsSameAsAgentAddress': False,
#    'BusinessID': 0,
#    'Status': None,
#    'MemberOrManager': 0,
#    'IsPrincipalOfficeNotInWa': False,
#    'IsFormation': False,
#    'IsNotRequired': False,
#    'IsACP': False,
#    'ParticipantNumber': None,
#    'IsForNonProfitAmendment': False,
#    'IsOldDataExist': False,
#    'FilerID': 0,
#    'UserID': 0,
#    'CreatedBy': 0,
#    'IPAddress': None,
#    'ModifiedBy': 0,
#    'ModifiedIPAddress': None},
#   'UploadDocuments': {'FileName': None,
#    'FileLocation': None,
#    'TempFileName': None,
#    'TempFileLocation': None,
#    'DocumentTypeId': 0,
#    'DocumentType': None,
#    'BusinessId': 0,
#    'BusinessFilingDocumentId': 0,
#    'FilingNo': 0,
#    'CreatedBy': 0,
#    'Status': None,
#    'TransactionID': 0,
#    'UploadFileName': None,
#    'IsPublicVisible': False,
#    'NumberOfPages': 0,
#    'FilingDateTime': '0001-01-01T00:00:00',
#    'Source': None,
#    'UserName': None,
#    'IsOnline': False,
#    'CartId': 0,
#    'UploadDocumentID': 0,
#    'DocumentTable': None,
#    'DocumentID': 0},
#   'OSOSCorpSignatureBlockEmail': None,
#   'OSOSCorpEmailSignature': None,
#   'OSOSCharitiesSignatureBlockEmail': None,
#   'BIIsOtherNAICS': False,
#   'BusinessHasActiveFilings': False,
#   'DisableFEIN': False,
#   'DisableUBI': False,
#   'EffectiveDateFlag': False,
#   'FilingSuccess': False,
#   'IsActiveFilingExist': False,
#   'IsAdditionalDocumentsExist': False,
#   'IsAgentEditShow': False,
#   'IsAgentMailingAddressReturnedMail': False,
#   'IsAgentStreetAddressReturnedMail': False,
#   'IsAmendmentAdoptionChange': False,
#   'IsAmendmentCorpSharesChange': False,
#   'IsAmendmentDelinquentStatus': False,
#   'IsAmendmentDurationChange': False,
#   'IsAmendmentEffectiveChange': False,
#   'IsAmendmentEntityNameChange': False,
#   'IsAmendmentEntityType': False,
#   'IsAmendmentPeriodofDuration': False,
#   'IsApplicantAddressReturnedMail': False,
#   'IsBatchJobSchedule': False,
#   'IsBusinessHide': False,
#   'isBusinessNameAvailable': False,
#   'IsCertificateofExistence': False,
#   'IsCertificateOfExistencePresent': False,
#   'IsCharitable': False,
#   'IsClientAddressReturnedMail': False,
#   'IsConsildationInCorp': False,
#   'IsCorrespondenceAddress': False,
#   'IsDBAInUse': False,
#   'isDBANameAvailable': False,
#   'IsDBASectionExist': False,
#   'IsDomesticUBI': False,
#   'IsEligibleFilingType': False,
#   'IsEmailOptionChecked': False,
#   'IsEmailOptionHide': False,
#   'IsFormation': False,
#   'IsFormationWithIntialReport': False,
#   'IsGrangeAddressReturnedMail': False,
#   'IsInhouseReviewOrFiling': False,
#   'IsInitialReportFiled': False,
#   'IsMeetingAddressReturnedMail': False,
#   'IsNameReserved': False,
#   'IsOnline': False,
#   'IsPerpetual': False,
#   'IsPOMailingAddressReturnedMail': False,
#   'IsPOStreetAddressReturnedMail': False,
#   'IsRALookupEnabled': False,
#   'IsReveiwPDFFieldsShow': False,
#   'IsSaveCloseWithInitialReport': False,
#   'IsTMApplicantAddressReturnedMail': False,
#   'IsTMOwnerAddressReturnedMail': False,
#   'isTradeMarkHide': False,
#   'IsTrademarkApplicantAddress': False,
#   'IsTrademarkOwnerAddress': False,
#   'IsTransactionFulfilled': False,
#   'IsUnansweredOrBlank': False,
#   'IsUploadDocumentExist': False,
#   'IsWalkInClose': False,
#   'IsWalkInSave': False,
#   'OnlineIsUBIChecked': False,
#   'validateUbiNumber': False,
#   'IsDORQuestionProperty': False,
#   'IsDORQuestionInterest16': False,
#   'IsDORQuestionInterest50': False,
#   'IsDORQuestionFuturePurchase': False,
#   'IsNewDORQuestionsAnswered': False,
#   'actionName': None,
#   'AgentId': 0,
#   'AgentName': 'CHANG LAW GROUP PC',
#   'AlternativeEmail': None,
#   'AmendedBusinessType': 0,
#   'AmendedBusinessTypeDesc': None,
#   'AnyOtherProvisions': None,
#   'Attention': None,
#   'AvailableStatus': None,
#   'BINAICSCode': None,
#   'BINAICSCodeDesc': None,
#   'BIOtherDescription': None,
#   'BusinessCategoryID': 0,
#   'BusinessCategory': None,
#   'BusinessID': 1537697,
#   'BusinessIDs': None,
#   'BusinessIndicator': None,
#   'BusinessName': 'TMUD GSL, LLC',
#   'BusinessStatus': 'Active',
#   'BusinessStatusID': 0,
#   'BusinessNameSearch': None,
#   'BusinessPartnershipEngages': None,
#   'BusinessType': 'FOREIGN LIMITED LIABILITY COMPANY',
#   'BusinessTypeID': 0,
#   'CartStatus': None,
#   'ConfirmationLetterDocumentID': 0,
#   'ConfirmationLetterFileName': None,
#   'CongratulationLetterFileName': None,
#   'controllerName': None,
#   'CorrespondenceEmailAddress': None,
#   'CorrespondenceFileName': None,
#   'createdBy': 0,
#   'createdIP': None,
#   'DateBeganDoingBusinessInWAType': None,
#   'DateOfAdoptionType': None,
#   'DBABusinessName': None,
#   'DocumentID': 0,
#   'DocumentTypeID': 0,
#   'DurationType': None,
#   'DurationYears': 0,
#   'EffectiveDateType': None,
#   'FileLocationOnlineInitialReport': None,
#   'FileLocationConfirmationLetter': None,
#   'FEINNo': None,
#   'FilingCorrespondenceAddressFileLocation': None,
#   'FilingCorrespondenceAddressFileName': None,
#   'FileLocationCongratulationLetter': None,
#   'FileLocationCorrespondence': None,
#   'FileLocationOnlineReport': None,
#   'FileLocationReceipt': None,
#   'InitialReportReviewHTML': None,
#   'IsAnnualReportFiledCount': 0,
#   'IsFeeWaiverFullFilledCount': 0,
#   'Jurisdiction': 0,
#   'JurisdictionCategory': None,
#   'JurisdictionCategoryReview': None,
#   'JurisdictionCountry': 0,
#   'JurisdictionCountryDesc': None,
#   'JurisdictionCountryDescReview': None,
#   'JurisdictionCountryReview': 0,
#   'JurisdictionDesc': None,
#   'JurisdictionDescReview': None,
#   'JurisdictionReview': 0,
#   'JurisdictionState': 0,
#   'JurisdictionStateDesc': None,
#   'JurisdictionStateDescReview': None,
#   'JurisdictionStateReview': 0,
#   'NewBusinessName': None,
#   'NewDBABusinessName': None,
#   'NameInHomeJurisdiction': None,
#   'NameReservedId': 0,
#   'NavigateUrl': None,
#   'NewBusinessStatusID': 0,
#   'NewFilingHistory': None,
#   'NewNameInHomeJurisdiction': None,
#   'NotificationAttention': None,
#   'OldBusinessName': None,
#   'OldDBABusinessName': None,
#   'OldFilingHistory': None,
#   'OldJurisdictionDesc': None,
#   'OnlineCartDraftID': 0,
#   'OnlineInitialReportFileName': None,
#   'OnlineInitialReportDocumentID': 0,
#   'OnlineLookupUBINo': None,
#   'OnlineNavigationUrl': None,
#   'OnlineReportDocumentID': 0,
#   'OnlineReportFileName': None,
#   'OtherProvisions': None,
#   'PlaceofFormationId': None,
#   'PurposeAndPowersID': 0,
#   'ReviewHTML': None,
#   'ReceiptFileName': None,
#   'ReprortAgentFullAddress': None,
#   'ReprortCorrespondenceFullAddress': None,
#   'ReprortFullAddress': None,
#   'SaveCloseExceptionCount': 0,
#   'SaveCloseNotesCount': 0,
#   'SeqNumber': 0,
#   'TempTableID': 0,
#   'TrademarkEnityName': None,
#   'TrademarkOwnerEntityName': None,
#   'TrademarkOwnerAddressFileName': None,
#   'TrademarkOwnerAddressFileNameLocation': None,
#   'TrademarkOwnerFullName': None,
#   'TrademarkOwnerFullAddress': None,
#   'TrademarkOwnerFirstName': None,
#   'TrademarkOwnerLastName': None,
#   'UBIBusinessType': None,
#   'UBIBusinessTypeID': 0,
#   'UBINumber': '604 874 529',
#   'HasMemberNonProfit': None,
#   'HasIncorporator': None,
#   'HasBoardOfDirectors': None,
#   'IsCanBePublicBenefitNonProfit': None,
#   'IsElectToBePublicBenefitNonProfit': None,
#   'IsRCWElection': None,
#   'IsNonProfitExempt': None,
#   'IsCanBeHostHome': None,
#   'NonProfitReporting1': None,
#   'NonProfitReporting2': None,
#   'IsAmendmentDeliquentStatus': False,
#   'IsIncorporatorSignatureAttestation': None,
#   'ExistingIsRCWElection': None,
#   'ExistingIsIncorporatorSignatureAttestation': None,
#   'ExistingIsCharitableNonProfit': None,
#   'ExistingIsHostHome': None,
#   'ExistingIsGrossRevenueNonProfit': None,
#   'ExistingIsPublicBenefitNonProfit': None,
#   'ExistingHasMemberNonProfit': None,
#   'ExistingFEINNo': None,
#   'IsHideBusinessInformationNPCheckboxes': False},
#  {'IsAvailable': False,
#   'PrincipalOffice': {'PrincipalID': 0,
#    'SequenceNo': 0,
#    'FirstName': None,
#    'LastName': None,
#    'FullName': None,
#    'Title': None,
#    'Name': None,
#    'MiddleName': None,
#    'PhoneNumber': None,
#    'EmailAddress': None,
#    'TypeID': None,
#    'PrincipalBaseType': None,
#    'PrincipalMailingAddress': {'Attention': None,
#     'NotificationAttention': None,
#     'CorrespondenceEmailAddress': None,
#     'ConsolidationCorrespondenceEmailAddress': None,
#     'ZipExtension': None,
#     'AddressEntityType': None,
#     'IsAddressSame': False,
#     'isUserNonCommercialRegisteredAgent': False,
#     'baseEntity': {'FilerID': 0,
#      'UserID': 0,
#      'CreatedBy': 0,
#      'IPAddress': None,
#      'ModifiedBy': 0,
#      'ModifiedIPAddress': None},
#     'IsInvalidState': False,
#     'IsAgentInWA': None,
#     'isRAStreetAddressValid': False,
#     'IsAddressReturnedMail': False,
#     'FullAddress': '',
#     'ID': 0,
#     'StreetAddress1': '',
#     'StreetAddress2': '',
#     'City': '',
#     'State': '',
#     'OtherState': '',
#     'Country': '',
#     'Zip5': '',
#     'Zip4': '',
#     'PostalCode': '',
#     'County': None,
#     'CountyName': None,
#     'CountryName': ''},
#    'PrincipalStreetAddress': {'Attention': None,
#     'NotificationAttention': None,
#     'CorrespondenceEmailAddress': None,
#     'ConsolidationCorrespondenceEmailAddress': None,
#     'ZipExtension': None,
#     'AddressEntityType': None,
#     'IsAddressSame': False,
#     'isUserNonCommercialRegisteredAgent': False,
#     'baseEntity': {'FilerID': 0,
#      'UserID': 0,
#      'CreatedBy': 0,
#      'IPAddress': None,
#      'ModifiedBy': 0,
#      'ModifiedIPAddress': None},
#     'IsInvalidState': False,
#     'IsAgentInWA': None,
#     'isRAStreetAddressValid': False,
#     'IsAddressReturnedMail': False,
#     'FullAddress': '',
#     'ID': 0,
#     'StreetAddress1': '',
#     'StreetAddress2': '',
#     'City': '',
#     'State': '',
#     'OtherState': '',
#     'Country': '',
#     'Zip5': '',
#     'Zip4': '',
#     'PostalCode': '',
#     'County': None,
#     'CountyName': None,
#     'CountryName': ''},
#    'IsSameAsMailingAddress': False,
#    'IsSameAsAgentAddress': False,
#    'BusinessID': 0,
#    'Status': None,
#    'MemberOrManager': 0,
#    'IsPrincipalOfficeNotInWa': False,
#    'IsFormation': False,
#    'IsNotRequired': False,
#    'IsACP': False,
#    'ParticipantNumber': None,
#    'IsForNonProfitAmendment': False,
#    'IsOldDataExist': False,
#    'FilerID': 0,
#    'UserID': 0,
#    'CreatedBy': 0,
#    'IPAddress': None,
#    'ModifiedBy': 0,
#    'ModifiedIPAddress': None},
#   'PrincipalOfficeInWA': None,
#   'Agent': {'Type': None,
#    'AgentID': 0,
#    'EntityName': None,
#    'OrganizationName': None,
#    'FirstName': None,
#    'LastName': None,
#    'IsNonCommercial': False,
#    'EmailAddress': None,
#    'AgentTypeID': 0,
#    'StreetAddress': {'Attention': None,
#     'NotificationAttention': None,
#     'CorrespondenceEmailAddress': None,
#     'ConsolidationCorrespondenceEmailAddress': None,
#     'ZipExtension': None,
#     'AddressEntityType': None,
#     'IsAddressSame': False,
#     'isUserNonCommercialRegisteredAgent': False,
#     'baseEntity': {'FilerID': 0,
#      'UserID': 0,
#      'CreatedBy': 0,
#      'IPAddress': None,
#      'ModifiedBy': 0,
#      'ModifiedIPAddress': None},
#     'IsInvalidState': False,
#     'IsAgentInWA': None,
#     'isRAStreetAddressValid': False,
#     'IsAddressReturnedMail': False,
#     'FullAddress': '',
#     'ID': 0,
#     'StreetAddress1': None,
#     'StreetAddress2': None,
#     'City': None,
#     'State': None,
#     'OtherState': None,
#     'Country': None,
#     'Zip5': None,
#     'Zip4': None,
#     'PostalCode': None,
#     'County': None,
#     'CountyName': None,
#     'CountryName': ''},
#    'MailingAddress': {'Attention': None,
#     'NotificationAttention': None,
#     'CorrespondenceEmailAddress': None,
#     'ConsolidationCorrespondenceEmailAddress': None,
#     'ZipExtension': None,
#     'AddressEntityType': None,
#     'IsAddressSame': False,
#     'isUserNonCommercialRegisteredAgent': False,
#     'baseEntity': {'FilerID': 0,
#      'UserID': 0,
#      'CreatedBy': 0,
#      'IPAddress': None,
#      'ModifiedBy': 0,
#      'ModifiedIPAddress': None},
#     'IsInvalidState': False,
#     'IsAgentInWA': None,
#     'isRAStreetAddressValid': False,
#     'IsAddressReturnedMail': False,
#     'FullAddress': '',
#     'ID': 0,
#     'StreetAddress1': None,
#     'StreetAddress2': None,
#     'City': None,
#     'State': None,
#     'OtherState': None,
#     'Country': None,
#     'Zip5': None,
#     'Zip4': None,
#     'PostalCode': None,
#     'County': None,
#     'CountyName': None,
#     'CountryName': ''},
#    'IsUserRegisteredAgent': False,
#    'PhoneNumber': None,
#    'IsRegisteredAgentConsent': False,
#    'Title': None,
#    'IsSameAsMailingAddress': False,
#    'CreatedBy': None,
#    'AgentCreatdDate': None,
#    'AgentCreatdIP': None,
#    'IsNewAgent': False,
#    'TotalCount': 0,
#    'IsAgentConsentShow': False,
#    'IsAgentChange': False,
#    'IsAgentFormation': False,
#    'OfficeOrPosition': '',
#    'BusinessIDForRA': 0,
#    'BusinessAgentAddressID': 0,
#    'BusinessAgentMailingAddressID': 0,
#    'IsAgentEdit': False,
#    'IsAgentAltered': False,
#    'IsOnlineAgent': False,
#    'Criteria': None,
#    'AgentStreet1': None,
#    'AgentStreet2': None,
#    'City': None,
#    'State': None,
#    'OtherState': None,
#    'PostalCode': None,
#    'Country': None,
#    'Zip4': None,
#    'Zip5': None,
#    'BusinessTypeID': 0,
#    'BusinessType': None,
#    'Jurisdiction': 0,
#    'JurisdictionDesc': None,
#    'JurisdictionState': 0,
#    'JurisdictionCountry': 0,
#    'JurisdictionStateDesc': None,
#    'JurisdictionCountryDesc': None,
#    'JurisdictionCategory': None,
#    'IsCRARegistration': False,
#    'IsCRAAttestation': False,
#    'IsCRANotification': False,
#    'IsCRAStatementofChanged': False,
#    'IsRepresentedAttestation': False,
#    'OldEntityName': None,
#    'OldFirstName': None,
#    'OldLastName': None,
#    'isStreetStateMustbeinWA': False,
#    'isMailingStateMustbeinWA': False,
#    'isRAAddressValid': False,
#    'IsAmendmentAgentInfoChange': False,
#    'IsRAOfficeorPositionSearch': False,
#    'FullName': '',
#    'AgentType': None,
#    'IsACP': False,
#    'ParticipantNumber': None},
#   'PrincipalsList': None,
#   'PrincipalName': None,
#   'SearchCriteria': None,
#   'SearchType': None,
#   'SearchTypeText': None,
#   'SearchValue': None,
#   'SearchEntityName': None,
#   'StartDateOfIncorporation': '0001-01-01T00:00:00',
#   'EndDateOfIncorporation': '0001-01-01T00:00:00',
#   'ExpirationDate': '0001-01-01T00:00:00',
#   'Criteria': None,
#   'GrangeAddress': None,
#   'MeetingPlace': None,
#   'IsOrgBusinessName': False,
#   'CheckBusinessName': None,
#   'PlusOrMinusOrder': 0,
#   'FiltereRecordId': 0,
#   'ModifiedDate': '0001-01-01T00:00:00',
#   'DissolutionDays': 0,
#   'ID': 0,
#   'isInhouse': False,
#   'FeeList': None,
#   'UBIStatus': None,
#   'IsUbiNumber': False,
#   'NewUBINumber': None,
#   'IsShowAdvanceSearch': False,
#   'EntityName': None,
#   'Status': None,
#   'Type': None,
#   'IsHostHomeSearch': None,
#   'IsPublicBenefitNonProfitSearch': None,
#   'IsCharitableNonProfitSearch': None,
#   'IsGrossRevenueNonProfitSearch': None,
#   'IsHasMembersSearch': None,
#   'IsHasFEINSearch': None,
#   'FEINNoSearch': None,
#   'IsHostHome': None,
#   'IsPublicBenefitNonProfit': None,
#   'IsCharitableNonProfit': None,
#   'IsGrossRevenueNonProfit': None,
#   'IsHasMembers': None,
#   'IsHasFEIN': None,
#   'EntityTypesWithScreens': {},
#   'AllScreenParts': {},
#   'OnlineReportPrincipalList': None,
#   'OnlineUploadDocumentsList': [],
#   'UploadDocumentsList': [],
#   'PrincipalMemberList': [],
#   'CorrespondenceAddress': {'Attention': None,
#    'NotificationAttention': None,
#    'CorrespondenceEmailAddress': None,
#    'ConsolidationCorrespondenceEmailAddress': None,
#    'ZipExtension': None,
#    'AddressEntityType': None,
#    'IsAddressSame': False,
#    'isUserNonCommercialRegisteredAgent': False,
#    'baseEntity': {'FilerID': 0,
#     'UserID': 0,
#     'CreatedBy': 0,
#     'IPAddress': None,
#     'ModifiedBy': 0,
#     'ModifiedIPAddress': None},
#    'IsInvalidState': False,
#    'IsAgentInWA': None,
#    'isRAStreetAddressValid': False,
#    'IsAddressReturnedMail': False,
#    'FullAddress': '',
#    'ID': 0,
#    'StreetAddress1': None,
#    'StreetAddress2': None,
#    'City': None,
#    'State': None,
#    'OtherState': None,
#    'Country': None,
#    'Zip5': None,
#    'Zip4': None,
#    'PostalCode': None,
#    'County': None,
#    'CountyName': None,
#    'CountryName': ''},
#   'OnlineReportAgent': {'Type': None,
#    'AgentID': 0,
#    'EntityName': None,
#    'OrganizationName': None,
#    'FirstName': None,
#    'LastName': None,
#    'IsNonCommercial': False,
#    'EmailAddress': None,
#    'AgentTypeID': 0,
#    'StreetAddress': {'Attention': None,
#     'NotificationAttention': None,
#     'CorrespondenceEmailAddress': None,
#     'ConsolidationCorrespondenceEmailAddress': None,
#     'ZipExtension': None,
#     'AddressEntityType': None,
#     'IsAddressSame': False,
#     'isUserNonCommercialRegisteredAgent': False,
#     'baseEntity': {'FilerID': 0,
#      'UserID': 0,
#      'CreatedBy': 0,
#      'IPAddress': None,
#      'ModifiedBy': 0,
#      'ModifiedIPAddress': None},
#     'IsInvalidState': False,
#     'IsAgentInWA': None,
#     'isRAStreetAddressValid': False,
#     'IsAddressReturnedMail': False,
#     'FullAddress': '',
#     'ID': 0,
#     'StreetAddress1': None,
#     'StreetAddress2': None,
#     'City': None,
#     'State': None,
#     'OtherState': None,
#     'Country': None,
#     'Zip5': None,
#     'Zip4': None,
#     'PostalCode': None,
#     'County': None,
#     'CountyName': None,
#     'CountryName': ''},
#    'MailingAddress': {'Attention': None,
#     'NotificationAttention': None,
#     'CorrespondenceEmailAddress': None,
#     'ConsolidationCorrespondenceEmailAddress': None,
#     'ZipExtension': None,
#     'AddressEntityType': None,
#     'IsAddressSame': False,
#     'isUserNonCommercialRegisteredAgent': False,
#     'baseEntity': {'FilerID': 0,
#      'UserID': 0,
#      'CreatedBy': 0,
#      'IPAddress': None,
#      'ModifiedBy': 0,
#      'ModifiedIPAddress': None},
#     'IsInvalidState': False,
#     'IsAgentInWA': None,
#     'isRAStreetAddressValid': False,
#     'IsAddressReturnedMail': False,
#     'FullAddress': '',
#     'ID': 0,
#     'StreetAddress1': None,
#     'StreetAddress2': None,
#     'City': None,
#     'State': None,
#     'OtherState': None,
#     'Country': None,
#     'Zip5': None,
#     'Zip4': None,
#     'PostalCode': None,
#     'County': None,
#     'CountyName': None,
#     'CountryName': ''},
#    'IsUserRegisteredAgent': False,
#    'PhoneNumber': None,
#    'IsRegisteredAgentConsent': False,
#    'Title': None,
#    'IsSameAsMailingAddress': False,
#    'CreatedBy': None,
#    'AgentCreatdDate': None,
#    'AgentCreatdIP': None,
#    'IsNewAgent': False,
#    'TotalCount': 0,
#    'IsAgentConsentShow': False,
#    'IsAgentChange': False,
#    'IsAgentFormation': False,
#    'OfficeOrPosition': None,
#    'BusinessIDForRA': 0,
#    'BusinessAgentAddressID': 0,
#    'BusinessAgentMailingAddressID': 0,
#    'IsAgentEdit': False,
#    'IsAgentAltered': False,
#    'IsOnlineAgent': False,
#    'Criteria': None,
#    'AgentStreet1': None,
#    'AgentStreet2': None,
#    'City': None,
#    'State': None,
#    'OtherState': None,
#    'PostalCode': None,
#    'Country': None,
#    'Zip4': None,
#    'Zip5': None,
#    'BusinessTypeID': 0,
#    'BusinessType': None,
#    'Jurisdiction': 0,
#    'JurisdictionDesc': None,
#    'JurisdictionState': 0,
#    'JurisdictionCountry': 0,
#    'JurisdictionStateDesc': None,
#    'JurisdictionCountryDesc': None,
#    'JurisdictionCategory': None,
#    'IsCRARegistration': False,
#    'IsCRAAttestation': False,
#    'IsCRANotification': False,
#    'IsCRAStatementofChanged': False,
#    'IsRepresentedAttestation': False,
#    'OldEntityName': None,
#    'OldFirstName': None,
#    'OldLastName': None,
#    'isStreetStateMustbeinWA': False,
#    'isMailingStateMustbeinWA': False,
#    'isRAAddressValid': False,
#    'IsAmendmentAgentInfoChange': False,
#    'IsRAOfficeorPositionSearch': False,
#    'FullName': '',
#    'AgentType': None,
#    'IsACP': False,
#    'ParticipantNumber': None},
#   'TrademarkOwnerAgent': {'Type': None,
#    'AgentID': 0,
#    'EntityName': None,
#    'OrganizationName': None,
#    'FirstName': None,
#    'LastName': None,
#    'IsNonCommercial': False,
#    'EmailAddress': None,
#    'AgentTypeID': 0,
#    'StreetAddress': {'Attention': None,
#     'NotificationAttention': None,
#     'CorrespondenceEmailAddress': None,
#     'ConsolidationCorrespondenceEmailAddress': None,
#     'ZipExtension': None,
#     'AddressEntityType': None,
#     'IsAddressSame': False,
#     'isUserNonCommercialRegisteredAgent': False,
#     'baseEntity': {'FilerID': 0,
#      'UserID': 0,
#      'CreatedBy': 0,
#      'IPAddress': None,
#      'ModifiedBy': 0,
#      'ModifiedIPAddress': None},
#     'IsInvalidState': False,
#     'IsAgentInWA': None,
#     'isRAStreetAddressValid': False,
#     'IsAddressReturnedMail': False,
#     'FullAddress': '',
#     'ID': 0,
#     'StreetAddress1': None,
#     'StreetAddress2': None,
#     'City': None,
#     'State': None,
#     'OtherState': None,
#     'Country': None,
#     'Zip5': None,
#     'Zip4': None,
#     'PostalCode': None,
#     'County': None,
#     'CountyName': None,
#     'CountryName': ''},
#    'MailingAddress': {'Attention': None,
#     'NotificationAttention': None,
#     'CorrespondenceEmailAddress': None,
#     'ConsolidationCorrespondenceEmailAddress': None,
#     'ZipExtension': None,
#     'AddressEntityType': None,
#     'IsAddressSame': False,
#     'isUserNonCommercialRegisteredAgent': False,
#     'baseEntity': {'FilerID': 0,
#      'UserID': 0,
#      'CreatedBy': 0,
#      'IPAddress': None,
#      'ModifiedBy': 0,
#      'ModifiedIPAddress': None},
#     'IsInvalidState': False,
#     'IsAgentInWA': None,
#     'isRAStreetAddressValid': False,
#     'IsAddressReturnedMail': False,
#     'FullAddress': '',
#     'ID': 0,
#     'StreetAddress1': None,
#     'StreetAddress2': None,
#     'City': None,
#     'State': None,
#     'OtherState': None,
#     'Country': None,
#     'Zip5': None,
#     'Zip4': None,
#     'PostalCode': None,
#     'County': None,
#     'CountyName': None,
#     'CountryName': ''},
# ...
#    'PersonType': None,
#    'IsRequired': False,
#    'AuthorizerName': None,
#    'ErrorMsgs': None,
#    'InhouseReviewHTML': None,
#    'InhouseInitialReportReviewHTML': None},
#   'OnlineReportBusinessTransaction': None,
#   'ARDueDate': '0001-01-01T00:00:00',
#   'createdDate': '0001-01-01T00:00:00',
#   'DateBeganDoingBusinessInWA': '0001-01-01T00:00:00',
#   'DateOfAdoption': '0001-01-01T00:00:00',
#   'DateOfFormationInHomeJurisdiction': '0001-01-01T00:00:00',
#   'DateOfIncorporation': '0001-01-01T00:00:00',
#   'DissolvedDate': '0001-01-01T00:00:00',
#   'EffectiveDate': '0001-01-01T00:00:00',
#   'ExpirationDateReview': '0001-01-01T00:00:00',
#   'FilingDate': '0001-01-01T00:00:00',
#   'NextARDueDate': '0001-01-01T00:00:00',
#   'PeriodofDurationDate': '0001-01-01T00:00:00',
#   'RAExpiredDate': '0001-01-01T00:00:00',
#   'ReinstatementDissolutionEndDate': '0001-01-01T00:00:00',
#   'RenewalDate': '0001-01-01T00:00:00',
#   'RequalificationTerminationEndDate': '0001-01-01T00:00:00',
#   'DurationExpireDate': None,
#   'InActiveDate': None,
#   'LastARFiledDate': '0001-01-01T00:00:00',
#   'NameReservationExpireDate': None,
#   'PeriodofDurationDateReview': None,
#   'OnlineReportNatureOfBusiness': None,
#   'OnlineCartEntity': None,
#   'BusinessInfoPrincipalOffice': {'PrincipalID': 0,
#    'SequenceNo': 0,
#    'FirstName': None,
#    'LastName': None,
#    'FullName': None,
#    'Title': None,
#    'Name': None,
#    'MiddleName': None,
#    'PhoneNumber': None,
#    'EmailAddress': None,
#    'TypeID': None,
#    'PrincipalBaseType': None,
#    'PrincipalMailingAddress': {'Attention': None,
#     'NotificationAttention': None,
#     'CorrespondenceEmailAddress': None,
#     'ConsolidationCorrespondenceEmailAddress': None,
#     'ZipExtension': None,
#     'AddressEntityType': None,
#     'IsAddressSame': False,
#     'isUserNonCommercialRegisteredAgent': False,
#     'baseEntity': {'FilerID': 0,
#      'UserID': 0,
#      'CreatedBy': 0,
#      'IPAddress': None,
#      'ModifiedBy': 0,
#      'ModifiedIPAddress': None},
#     'IsInvalidState': False,
#     'IsAgentInWA': None,
#     'isRAStreetAddressValid': False,
#     'IsAddressReturnedMail': False,
#     'FullAddress': '',
#     'ID': 0,
#     'StreetAddress1': None,
#     'StreetAddress2': None,
#     'City': None,
#     'State': None,
#     'OtherState': None,
#     'Country': None,
#     'Zip5': None,
#     'Zip4': None,
#     'PostalCode': None,
#     'County': None,
#     'CountyName': None,
#     'CountryName': ''},
#    'PrincipalStreetAddress': {'Attention': None,
#     'NotificationAttention': None,
#     'CorrespondenceEmailAddress': None,
#     'ConsolidationCorrespondenceEmailAddress': None,
#     'ZipExtension': None,
#     'AddressEntityType': None,
#     'IsAddressSame': False,
#     'isUserNonCommercialRegisteredAgent': False,
#     'baseEntity': {'FilerID': 0,
#      'UserID': 0,
#      'CreatedBy': 0,
#      'IPAddress': None,
#      'ModifiedBy': 0,
#      'ModifiedIPAddress': None},
#     'IsInvalidState': False,
#     'IsAgentInWA': None,
#     'isRAStreetAddressValid': False,
#     'IsAddressReturnedMail': False,
#     'FullAddress': '',
#     'ID': 0,
#     'StreetAddress1': None,
#     'StreetAddress2': None,
#     'City': None,
#     'State': None,
#     'OtherState': None,
#     'Country': None,
#     'Zip5': None,
#     'Zip4': None,
#     'PostalCode': None,
#     'County': None,
#     'CountyName': None,
#     'CountryName': ''},
#    'IsSameAsMailingAddress': False,
#    'IsSameAsAgentAddress': False,
#    'BusinessID': 0,
#    'Status': None,
#    'MemberOrManager': 0,
#    'IsPrincipalOfficeNotInWa': False,
#    'IsFormation': False,
#    'IsNotRequired': False,
#    'IsACP': False,
#    'ParticipantNumber': None,
#    'IsForNonProfitAmendment': False,
#    'IsOldDataExist': False,
#    'FilerID': 0,
#    'UserID': 0,
#    'CreatedBy': 0,
#    'IPAddress': None,
#    'ModifiedBy': 0,
#    'ModifiedIPAddress': None},
#   'BusinessInfoPrincipalOfficeInWA': {'PrincipalID': 0,
#    'SequenceNo': 0,
#    'FirstName': None,
#    'LastName': None,
#    'FullName': None,
#    'Title': None,
#    'Name': None,
#    'MiddleName': None,
#    'PhoneNumber': None,
#    'EmailAddress': None,
#    'TypeID': None,
#    'PrincipalBaseType': None,
#    'PrincipalMailingAddress': {'Attention': None,
#     'NotificationAttention': None,
#     'CorrespondenceEmailAddress': None,
#     'ConsolidationCorrespondenceEmailAddress': None,
#     'ZipExtension': None,
#     'AddressEntityType': None,
#     'IsAddressSame': False,
#     'isUserNonCommercialRegisteredAgent': False,
#     'baseEntity': {'FilerID': 0,
#      'UserID': 0,
#      'CreatedBy': 0,
#      'IPAddress': None,
#      'ModifiedBy': 0,
#      'ModifiedIPAddress': None},
#     'IsInvalidState': False,
#     'IsAgentInWA': None,
#     'isRAStreetAddressValid': False,
#     'IsAddressReturnedMail': False,
#     'FullAddress': '',
#     'ID': 0,
#     'StreetAddress1': None,
#     'StreetAddress2': None,
#     'City': None,
#     'State': None,
#     'OtherState': None,
#     'Country': None,
#     'Zip5': None,
#     'Zip4': None,
#     'PostalCode': None,
#     'County': None,
#     'CountyName': None,
#     'CountryName': ''},
#    'PrincipalStreetAddress': {'Attention': None,
#     'NotificationAttention': None,
#     'CorrespondenceEmailAddress': None,
#     'ConsolidationCorrespondenceEmailAddress': None,
#     'ZipExtension': None,
#     'AddressEntityType': None,
#     'IsAddressSame': False,
#     'isUserNonCommercialRegisteredAgent': False,
#     'baseEntity': {'FilerID': 0,
#      'UserID': 0,
#      'CreatedBy': 0,
#      'IPAddress': None,
#      'ModifiedBy': 0,
#      'ModifiedIPAddress': None},
#     'IsInvalidState': False,
#     'IsAgentInWA': None,
#     'isRAStreetAddressValid': False,
#     'IsAddressReturnedMail': False,
#     'FullAddress': '',
#     'ID': 0,
#     'StreetAddress1': None,
#     'StreetAddress2': None,
#     'City': None,
#     'State': None,
#     'OtherState': None,
#     'Country': None,
#     'Zip5': None,
#     'Zip4': None,
#     'PostalCode': None,
#     'County': None,
#     'CountyName': None,
#     'CountryName': ''},
#    'IsSameAsMailingAddress': False,
#    'IsSameAsAgentAddress': False,
#    'BusinessID': 0,
#    'Status': None,
#    'MemberOrManager': 0,
#    'IsPrincipalOfficeNotInWa': False,
#    'IsFormation': False,
#    'IsNotRequired': False,
#    'IsACP': False,
#    'ParticipantNumber': None,
#    'IsForNonProfitAmendment': False,
#    'IsOldDataExist': False,
#    'FilerID': 0,
#    'UserID': 0,
#    'CreatedBy': 0,
#    'IPAddress': None,
#    'ModifiedBy': 0,
#    'ModifiedIPAddress': None},
#   'OnlineReportPrincipalOffice': {'PrincipalID': 0,
#    'SequenceNo': 0,
#    'FirstName': None,
#    'LastName': None,
#    'FullName': None,
#    'Title': None,
#    'Name': None,
#    'MiddleName': None,
#    'PhoneNumber': None,
#    'EmailAddress': None,
#    'TypeID': None,
#    'PrincipalBaseType': None,
#    'PrincipalMailingAddress': {'Attention': None,
#     'NotificationAttention': None,
#     'CorrespondenceEmailAddress': None,
#     'ConsolidationCorrespondenceEmailAddress': None,
#     'ZipExtension': None,
#     'AddressEntityType': None,
#     'IsAddressSame': False,
#     'isUserNonCommercialRegisteredAgent': False,
#     'baseEntity': {'FilerID': 0,
#      'UserID': 0,
#      'CreatedBy': 0,
#      'IPAddress': None,
#      'ModifiedBy': 0,
#      'ModifiedIPAddress': None},
#     'IsInvalidState': False,
#     'IsAgentInWA': None,
#     'isRAStreetAddressValid': False,
#     'IsAddressReturnedMail': False,
#     'FullAddress': '',
#     'ID': 0,
#     'StreetAddress1': None,
#     'StreetAddress2': None,
#     'City': None,
#     'State': None,
#     'OtherState': None,
#     'Country': None,
#     'Zip5': None,
#     'Zip4': None,
#     'PostalCode': None,
#     'County': None,
#     'CountyName': None,
#     'CountryName': ''},
#    'PrincipalStreetAddress': {'Attention': None,
#     'NotificationAttention': None,
#     'CorrespondenceEmailAddress': None,
#     'ConsolidationCorrespondenceEmailAddress': None,
#     'ZipExtension': None,
#     'AddressEntityType': None,
#     'IsAddressSame': False,
#     'isUserNonCommercialRegisteredAgent': False,
#     'baseEntity': {'FilerID': 0,
#      'UserID': 0,
#      'CreatedBy': 0,
#      'IPAddress': None,
#      'ModifiedBy': 0,
#      'ModifiedIPAddress': None},
#     'IsInvalidState': False,
#     'IsAgentInWA': None,
#     'isRAStreetAddressValid': False,
#     'IsAddressReturnedMail': False,
#     'FullAddress': '',
#     'ID': 0,
#     'StreetAddress1': None,
#     'StreetAddress2': None,
#     'City': None,
#     'State': None,
#     'OtherState': None,
#     'Country': None,
#     'Zip5': None,
#     'Zip4': None,
#     'PostalCode': None,
#     'County': None,
#     'CountyName': None,
#     'CountryName': ''},
#    'IsSameAsMailingAddress': False,
#    'IsSameAsAgentAddress': False,
#    'BusinessID': 0,
#    'Status': None,
#    'MemberOrManager': 0,
#    'IsPrincipalOfficeNotInWa': False,
#    'IsFormation': False,
#    'IsNotRequired': False,
#    'IsACP': False,
#    'ParticipantNumber': None,
#    'IsForNonProfitAmendment': False,
#    'IsOldDataExist': False,
#    'FilerID': 0,
#    'UserID': 0,
#    'CreatedBy': 0,
#    'IPAddress': None,
#    'ModifiedBy': 0,
#    'ModifiedIPAddress': None},
#   'UploadDocuments': {'FileName': None,
#    'FileLocation': None,
#    'TempFileName': None,
#    'TempFileLocation': None,
#    'DocumentTypeId': 0,
#    'DocumentType': None,
#    'BusinessId': 0,
#    'BusinessFilingDocumentId': 0,
#    'FilingNo': 0,
#    'CreatedBy': 0,
#    'Status': None,
#    'TransactionID': 0,
#    'UploadFileName': None,
#    'IsPublicVisible': False,
#    'NumberOfPages': 0,
#    'FilingDateTime': '0001-01-01T00:00:00',
#    'Source': None,
#    'UserName': None,
#    'IsOnline': False,
#    'CartId': 0,
#    'UploadDocumentID': 0,
#    'DocumentTable': None,
#    'DocumentID': 0},
#   'OSOSCorpSignatureBlockEmail': None,
#   'OSOSCorpEmailSignature': None,
#   'OSOSCharitiesSignatureBlockEmail': None,
#   'BIIsOtherNAICS': False,
#   'BusinessHasActiveFilings': False,
#   'DisableFEIN': False,
#   'DisableUBI': False,
#   'EffectiveDateFlag': False,
#   'FilingSuccess': False,
#   'IsActiveFilingExist': False,
#   'IsAdditionalDocumentsExist': False,
#   'IsAgentEditShow': False,
#   'IsAgentMailingAddressReturnedMail': False,
#   'IsAgentStreetAddressReturnedMail': False,
#   'IsAmendmentAdoptionChange': False,
#   'IsAmendmentCorpSharesChange': False,
#   'IsAmendmentDelinquentStatus': False,
#   'IsAmendmentDurationChange': False,
#   'IsAmendmentEffectiveChange': False,
#   'IsAmendmentEntityNameChange': False,
#   'IsAmendmentEntityType': False,
#   'IsAmendmentPeriodofDuration': False,
#   'IsApplicantAddressReturnedMail': False,
#   'IsBatchJobSchedule': False,
#   'IsBusinessHide': False,
#   'isBusinessNameAvailable': False,
#   'IsCertificateofExistence': False,
#   'IsCertificateOfExistencePresent': False,
#   'IsCharitable': False,
#   'IsClientAddressReturnedMail': False,
#   'IsConsildationInCorp': False,
#   'IsCorrespondenceAddress': False,
#   'IsDBAInUse': False,
#   'isDBANameAvailable': False,
#   'IsDBASectionExist': False,
#   'IsDomesticUBI': False,
#   'IsEligibleFilingType': False,
#   'IsEmailOptionChecked': False,
#   'IsEmailOptionHide': False,
#   'IsFormation': False,
#   'IsFormationWithIntialReport': False,
#   'IsGrangeAddressReturnedMail': False,
#   'IsInhouseReviewOrFiling': False,
#   'IsInitialReportFiled': False,
#   'IsMeetingAddressReturnedMail': False,
#   'IsNameReserved': False,
#   'IsOnline': False,
#   'IsPerpetual': False,
#   'IsPOMailingAddressReturnedMail': False,
#   'IsPOStreetAddressReturnedMail': False,
#   'IsRALookupEnabled': False,
#   'IsReveiwPDFFieldsShow': False,
#   'IsSaveCloseWithInitialReport': False,
#   'IsTMApplicantAddressReturnedMail': False,
#   'IsTMOwnerAddressReturnedMail': False,
#   'isTradeMarkHide': False,
#   'IsTrademarkApplicantAddress': False,
#   'IsTrademarkOwnerAddress': False,
#   'IsTransactionFulfilled': False,
#   'IsUnansweredOrBlank': False,
#   'IsUploadDocumentExist': False,
#   'IsWalkInClose': False,
#   'IsWalkInSave': False,
#   'OnlineIsUBIChecked': False,
#   'validateUbiNumber': False,
#   'IsDORQuestionProperty': False,
#   'IsDORQuestionInterest16': False,
#   'IsDORQuestionInterest50': False,
#   'IsDORQuestionFuturePurchase': False,
#   'IsNewDORQuestionsAnswered': False,
#   'actionName': None,
#   'AgentId': 0,
#   'AgentName': 'CHANG LAW GROUP PC',
#   'AlternativeEmail': None,
#   'AmendedBusinessType': 0,
#   'AmendedBusinessTypeDesc': None,
#   'AnyOtherProvisions': None,
#   'Attention': None,
#   'AvailableStatus': None,
#   'BINAICSCode': None,
#   'BINAICSCodeDesc': None,
#   'BIOtherDescription': None,
#   'BusinessCategoryID': 0,
#   'BusinessCategory': None,
#   'BusinessID': 1518300,
#   'BusinessIDs': None,
#   'BusinessIndicator': None,
#   'BusinessName': 'TMUD-IDMGT, LLC',
#   'BusinessStatus': 'Active',
#   'BusinessStatusID': 0,
#   'BusinessNameSearch': None,
#   'BusinessPartnershipEngages': None,
#   'BusinessType': 'WA LIMITED LIABILITY COMPANY',
#   'BusinessTypeID': 0,
#   'CartStatus': None,
#   'ConfirmationLetterDocumentID': 0,
#   'ConfirmationLetterFileName': None,
#   'CongratulationLetterFileName': None,
#   'controllerName': None,
#   'CorrespondenceEmailAddress': None,
#   'CorrespondenceFileName': None,
#   'createdBy': 0,
#   'createdIP': None,
#   'DateBeganDoingBusinessInWAType': None,
#   'DateOfAdoptionType': None,
#   'DBABusinessName': None,
#   'DocumentID': 0,
#   'DocumentTypeID': 0,
#   'DurationType': None,
#   'DurationYears': 0,
#   'EffectiveDateType': None,
#   'FileLocationOnlineInitialReport': None,
#   'FileLocationConfirmationLetter': None,
#   'FEINNo': None,
#   'FilingCorrespondenceAddressFileLocation': None,
#   'FilingCorrespondenceAddressFileName': None,
#   'FileLocationCongratulationLetter': None,
#   'FileLocationCorrespondence': None,
#   'FileLocationOnlineReport': None,
#   'FileLocationReceipt': None,
#   'InitialReportReviewHTML': None,
#   'IsAnnualReportFiledCount': 0,
#   'IsFeeWaiverFullFilledCount': 0,
#   'Jurisdiction': 0,
#   'JurisdictionCategory': None,
#   'JurisdictionCategoryReview': None,
#   'JurisdictionCountry': 0,
#   'JurisdictionCountryDesc': None,
#   'JurisdictionCountryDescReview': None,
#   'JurisdictionCountryReview': 0,
#   'JurisdictionDesc': None,
#   'JurisdictionDescReview': None,
#   'JurisdictionReview': 0,
#   'JurisdictionState': 0,
#   'JurisdictionStateDesc': None,
#   'JurisdictionStateDescReview': None,
#   'JurisdictionStateReview': 0,
#   'NewBusinessName': None,
#   'NewDBABusinessName': None,
#   'NameInHomeJurisdiction': None,
#   'NameReservedId': 0,
#   'NavigateUrl': None,
#   'NewBusinessStatusID': 0,
#   'NewFilingHistory': None,
#   'NewNameInHomeJurisdiction': None,
#   'NotificationAttention': None,
#   'OldBusinessName': None,
#   'OldDBABusinessName': None,
#   'OldFilingHistory': None,
#   'OldJurisdictionDesc': None,
#   'OnlineCartDraftID': 0,
#   'OnlineInitialReportFileName': None,
#   'OnlineInitialReportDocumentID': 0,
#   'OnlineLookupUBINo': None,
#   'OnlineNavigationUrl': None,
#   'OnlineReportDocumentID': 0,
#   'OnlineReportFileName': None,
#   'OtherProvisions': None,
#   'PlaceofFormationId': None,
#   'PurposeAndPowersID': 0,
#   'ReviewHTML': None,
#   'ReceiptFileName': None,
#   'ReprortAgentFullAddress': None,
#   'ReprortCorrespondenceFullAddress': None,
#   'ReprortFullAddress': None,
#   'SaveCloseExceptionCount': 0,
#   'SaveCloseNotesCount': 0,
#   'SeqNumber': 0,
#   'TempTableID': 0,
#   'TrademarkEnityName': None,
#   'TrademarkOwnerEntityName': None,
#   'TrademarkOwnerAddressFileName': None,
#   'TrademarkOwnerAddressFileNameLocation': None,
#   'TrademarkOwnerFullName': None,
#   'TrademarkOwnerFullAddress': None,
#   'TrademarkOwnerFirstName': None,
#   'TrademarkOwnerLastName': None,
#   'UBIBusinessType': None,
#   'UBIBusinessTypeID': 0,
#   'UBINumber': '604 848 437',
#   'HasMemberNonProfit': None,
#   'HasIncorporator': None,
#   'HasBoardOfDirectors': None,
#   'IsCanBePublicBenefitNonProfit': None,
#   'IsElectToBePublicBenefitNonProfit': None,
#   'IsRCWElection': None,
#   'IsNonProfitExempt': None,
#   'IsCanBeHostHome': None,
#   'NonProfitReporting1': None,
#   'NonProfitReporting2': None,
#   'IsAmendmentDeliquentStatus': False,
#   'IsIncorporatorSignatureAttestation': None,
#   'ExistingIsRCWElection': None,
#   'ExistingIsIncorporatorSignatureAttestation': None,
#   'ExistingIsCharitableNonProfit': None,
#   'ExistingIsHostHome': None,
#   'ExistingIsGrossRevenueNonProfit': None,
#   'ExistingIsPublicBenefitNonProfit': None,
#   'ExistingHasMemberNonProfit': None,
#   'ExistingFEINNo': None,
#   'IsHideBusinessInformationNPCheckboxes': False}]

# %%
def extract_search_results(search_term, search_req_response):
    res_list = [[search_term, res['BusinessName'], res['UBINumber'], res['BusinessID'], res['PrincipalOffice']['PrincipalStreetAddress']['FullAddress']] for res in search_req_response]
    return pd.DataFrame(res_list, columns=['SearchTerm', 'BusinessName', 'UBINumber', 'BusinessId', 'Address'])

test_search_results_df = extract_search_results('TMUD GSL LLC', test_search_req)
test_search_results_df
# Out:
#      SearchTerm     BusinessName    UBINumber  BusinessId  \
# 0  TMUD GSL LLC    TMUD GSL, LLC  604 874 529     1537697
# 1  TMUD GSL LLC    TMUD GSL, LLC  604 848 437     1518300
# 2  TMUD GSL LLC  TMUD-IDMGT, LLC  604 848 437     1518300
#
#                                              Address
# 0  11010 NE 8TH ST STE 465, BELLEVUE, WA, 98004-4...
# 1
# 2  11010 NE 8TH ST STE 465, BELLEVUE, WA, 98004-4...

# %%
# Mark row as potential match if: name is similar, UBI number is a duplicate, or Address is the same
def determine_search_matches(search_results_df):
    name_match = search_results_df.apply(lambda x: fuzz.ratio(x['SearchTerm'], x['BusinessName']) > 90, axis=1)
    meta_match = search_results_df.duplicated(subset=['Address'], keep=False) | search_results_df.duplicated(subset=['UBINumber'], keep=False) | search_results_df.duplicated(subset=['BusinessId'], keep=False)
    search_results_df['IsMatch'] = name_match | meta_match

# %%
determine_search_matches(test_search_results_df)
test_search_results_df
# Out:
#      SearchTerm     BusinessName    UBINumber  BusinessId  \
# 0  TMUD GSL LLC    TMUD GSL, LLC  604 874 529     1537697
# 1  TMUD GSL LLC    TMUD GSL, LLC  604 848 437     1518300
# 2  TMUD GSL LLC  TMUD-IDMGT, LLC  604 848 437     1518300
#
#                                              Address  IsMatch
# 0  11010 NE 8TH ST STE 465, BELLEVUE, WA, 98004-4...     True
# 1                                                        True
# 2  11010 NE 8TH ST STE 465, BELLEVUE, WA, 98004-4...     True

# %%
def get_business_details(business_id):
    url = 'https://cfda.sos.wa.gov/api/BusinessSearch/BusinessInformation?businessID={business_id}'.format(business_id=business_id)
    r = requests.get(url)
    return json.loads(r.text)

# %%
dets = get_business_details(1537697)
dets
# Out:
# {'IsAvailable': False,
#  'PrincipalOffice': {'PrincipalID': 0,
#   'SequenceNo': 0,
#   'FirstName': None,
#   'LastName': None,
#   'FullName': None,
#   'Title': None,
#   'Name': None,
#   'MiddleName': None,
#   'PhoneNumber': '',
#   'EmailAddress': 'INFO@CHANGLAWGROUP.COM',
#   'TypeID': None,
#   'PrincipalBaseType': None,
#   'PrincipalMailingAddress': {'Attention': None,
#    'NotificationAttention': None,
#    'CorrespondenceEmailAddress': None,
#    'ConsolidationCorrespondenceEmailAddress': None,
#    'ZipExtension': None,
#    'AddressEntityType': None,
#    'IsAddressSame': False,
#    'isUserNonCommercialRegisteredAgent': False,
#    'baseEntity': {'FilerID': 0,
#     'UserID': 0,
#     'CreatedBy': 0,
#     'IPAddress': None,
#     'ModifiedBy': 0,
#     'ModifiedIPAddress': None},
#    'IsInvalidState': False,
#    'IsAgentInWA': None,
#    'isRAStreetAddressValid': False,
#    'IsAddressReturnedMail': False,
#    'FullAddress': '11010 NE 8TH ST STE 465, BELLEVUE, WA, 98004-4408, UNITED STATES',
#    'ID': 2668350,
#    'StreetAddress1': '11010 NE 8TH ST STE 465',
#    'StreetAddress2': '',
#    'City': 'BELLEVUE',
#    'State': 'WA',
#    'OtherState': '',
#    'Country': 'USA',
#    'Zip5': '98004',
#    'Zip4': '4408',
#    'PostalCode': '',
#    'County': None,
#    'CountyName': None,
#    'CountryName': 'UNITED STATES'},
#   'PrincipalStreetAddress': {'Attention': None,
#    'NotificationAttention': None,
#    'CorrespondenceEmailAddress': None,
#    'ConsolidationCorrespondenceEmailAddress': None,
#    'ZipExtension': None,
#    'AddressEntityType': None,
#    'IsAddressSame': False,
#    'isUserNonCommercialRegisteredAgent': False,
#    'baseEntity': {'FilerID': 0,
#     'UserID': 0,
#     'CreatedBy': 0,
#     'IPAddress': None,
#     'ModifiedBy': 0,
#     'ModifiedIPAddress': None},
#    'IsInvalidState': False,
#    'IsAgentInWA': None,
#    'isRAStreetAddressValid': False,
#    'IsAddressReturnedMail': False,
#    'FullAddress': '11010 NE 8TH ST STE 465, BELLEVUE, WA, 98004-4408, UNITED STATES',
#    'ID': 2668349,
#    'StreetAddress1': '11010 NE 8TH ST STE 465',
#    'StreetAddress2': '',
#    'City': 'BELLEVUE',
#    'State': 'WA',
#    'OtherState': '',
#    'Country': 'USA',
#    'Zip5': '98004',
#    'Zip4': '4408',
#    'PostalCode': '',
#    'County': None,
#    'CountyName': None,
#    'CountryName': 'UNITED STATES'},
#   'IsSameAsMailingAddress': False,
#   'IsSameAsAgentAddress': False,
#   'BusinessID': 0,
#   'Status': None,
#   'MemberOrManager': 0,
#   'IsPrincipalOfficeNotInWa': False,
#   'IsFormation': False,
#   'IsNotRequired': False,
#   'IsACP': False,
#   'ParticipantNumber': None,
#   'IsForNonProfitAmendment': False,
#   'IsOldDataExist': True,
#   'FilerID': 0,
#   'UserID': 0,
#   'CreatedBy': 0,
#   'IPAddress': None,
#   'ModifiedBy': 0,
#   'ModifiedIPAddress': None},
#  'PrincipalOfficeInWA': None,
#  'Agent': {'Type': None,
#   'AgentID': 1139540,
#   'EntityName': 'CHANG LAW GROUP PC',
#   'OrganizationName': None,
#   'FirstName': '',
#   'LastName': '',
#   'IsNonCommercial': False,
#   'EmailAddress': 'INFO@CHANGLAWGROUP.COM',
#   'AgentTypeID': 0,
#   'StreetAddress': {'Attention': None,
#    'NotificationAttention': None,
#    'CorrespondenceEmailAddress': None,
#    'ConsolidationCorrespondenceEmailAddress': None,
#    'ZipExtension': None,
#    'AddressEntityType': None,
#    'IsAddressSame': False,
#    'isUserNonCommercialRegisteredAgent': False,
#    'baseEntity': {'FilerID': 0,
#     'UserID': 0,
#     'CreatedBy': 0,
#     'IPAddress': None,
#     'ModifiedBy': 0,
#     'ModifiedIPAddress': None},
#    'IsInvalidState': False,
#    'IsAgentInWA': None,
#    'isRAStreetAddressValid': False,
#    'IsAddressReturnedMail': False,
#    'FullAddress': '3006 NORTHUP WAY, SUITE 100, BELLEVUE, WA, 98004-1445, UNITED STATES',
#    'ID': 2280484,
#    'StreetAddress1': '3006 NORTHUP WAY',
#    'StreetAddress2': 'SUITE 100',
#    'City': 'BELLEVUE',
#    'State': 'WA',
#    'OtherState': '',
#    'Country': 'USA',
#    'Zip5': '98004',
#    'Zip4': '1445',
#    'PostalCode': '',
#    'County': None,
#    'CountyName': None,
#    'CountryName': 'UNITED STATES'},
#   'MailingAddress': {'Attention': None,
#    'NotificationAttention': None,
#    'CorrespondenceEmailAddress': None,
#    'ConsolidationCorrespondenceEmailAddress': None,
#    'ZipExtension': None,
#    'AddressEntityType': None,
#    'IsAddressSame': False,
#    'isUserNonCommercialRegisteredAgent': False,
#    'baseEntity': {'FilerID': 0,
#     'UserID': 0,
#     'CreatedBy': 0,
#     'IPAddress': None,
#     'ModifiedBy': 0,
#     'ModifiedIPAddress': None},
#    'IsInvalidState': False,
#    'IsAgentInWA': None,
#    'isRAStreetAddressValid': False,
#    'IsAddressReturnedMail': False,
#    'FullAddress': '3006 NORTHUP WAY, SUITE 100, BELLEVUE, WA, 98004-1445, UNITED STATES',
#    'ID': 2280485,
#    'StreetAddress1': '3006 NORTHUP WAY',
#    'StreetAddress2': 'SUITE 100',
#    'City': 'BELLEVUE',
#    'State': 'WA',
#    'OtherState': '',
#    'Country': 'USA',
#    'Zip5': '98004',
#    'Zip4': '1445',
#    'PostalCode': '',
#    'County': None,
#    'CountyName': None,
#    'CountryName': 'UNITED STATES'},
#   'IsUserRegisteredAgent': False,
#   'PhoneNumber': '',
#   'IsRegisteredAgentConsent': True,
#   'Title': None,
#   'IsSameAsMailingAddress': False,
#   'CreatedBy': None,
#   'AgentCreatdDate': None,
#   'AgentCreatdIP': None,
#   'IsNewAgent': False,
#   'TotalCount': 0,
#   'IsAgentConsentShow': False,
#   'IsAgentChange': False,
#   'IsAgentFormation': False,
#   'OfficeOrPosition': '',
#   'BusinessIDForRA': 0,
#   'BusinessAgentAddressID': 0,
#   'BusinessAgentMailingAddressID': 0,
#   'IsAgentEdit': False,
#   'IsAgentAltered': False,
#   'IsOnlineAgent': False,
#   'Criteria': None,
#   'AgentStreet1': None,
#   'AgentStreet2': None,
#   'City': None,
#   'State': None,
#   'OtherState': None,
#   'PostalCode': None,
#   'Country': None,
#   'Zip4': None,
#   'Zip5': None,
#   'BusinessTypeID': 0,
#   'BusinessType': None,
#   'Jurisdiction': 0,
#   'JurisdictionDesc': None,
#   'JurisdictionState': 0,
#   'JurisdictionCountry': 0,
#   'JurisdictionStateDesc': None,
#   'JurisdictionCountryDesc': None,
#   'JurisdictionCategory': None,
#   'IsCRARegistration': False,
#   'IsCRAAttestation': False,
#   'IsCRANotification': False,
#   'IsCRAStatementofChanged': False,
#   'IsRepresentedAttestation': False,
#   'OldEntityName': None,
#   'OldFirstName': None,
#   'OldLastName': None,
#   'isStreetStateMustbeinWA': False,
#   'isMailingStateMustbeinWA': False,
#   'isRAAddressValid': False,
#   'IsAmendmentAgentInfoChange': False,
#   'IsRAOfficeorPositionSearch': False,
#   'FullName': 'CHANG LAW GROUP PC',
#   'AgentType': 'E',
#   'IsACP': False,
#   'ParticipantNumber': None},
#  'PrincipalsList': [{'PrincipalID': 3778468,
#    'SequenceNo': 0,
#    'FirstName': '',
#    'LastName': '',
#    'FullName': None,
#    'Title': '',
#    'Name': 'TMUD-IDMGT, LLC',
#    'MiddleName': None,
#    'PhoneNumber': None,
#    'EmailAddress': None,
#    'TypeID': 'E',
#    'PrincipalBaseType': 'GoverningPerson',
#    'PrincipalMailingAddress': {'Attention': None,
#     'NotificationAttention': None,
#     'CorrespondenceEmailAddress': None,
#     'ConsolidationCorrespondenceEmailAddress': None,
#     'ZipExtension': None,
#     'AddressEntityType': None,
#     'IsAddressSame': False,
#     'isUserNonCommercialRegisteredAgent': False,
#     'baseEntity': {'FilerID': 0,
#      'UserID': 0,
#      'CreatedBy': 0,
#      'IPAddress': None,
#      'ModifiedBy': 0,
#      'ModifiedIPAddress': None},
#     'IsInvalidState': False,
#     'IsAgentInWA': None,
#     'isRAStreetAddressValid': False,
#     'IsAddressReturnedMail': False,
#     'FullAddress': '',
#     'ID': 0,
#     'StreetAddress1': None,
#     'StreetAddress2': None,
#     'City': None,
#     'State': None,
#     'OtherState': None,
#     'Country': None,
#     'Zip5': None,
#     'Zip4': None,
#     'PostalCode': None,
#     'County': None,
#     'CountyName': None,
#     'CountryName': ''},
#    'PrincipalStreetAddress': {'Attention': None,
#     'NotificationAttention': None,
#     'CorrespondenceEmailAddress': None,
#     'ConsolidationCorrespondenceEmailAddress': None,
#     'ZipExtension': None,
#     'AddressEntityType': None,
#     'IsAddressSame': False,
#     'isUserNonCommercialRegisteredAgent': False,
#     'baseEntity': {'FilerID': 0,
#      'UserID': 0,
#      'CreatedBy': 0,
#      'IPAddress': None,
#      'ModifiedBy': 0,
#      'ModifiedIPAddress': None},
#     'IsInvalidState': False,
#     'IsAgentInWA': None,
#     'isRAStreetAddressValid': False,
#     'IsAddressReturnedMail': False,
#     'FullAddress': '',
#     'ID': 0,
#     'StreetAddress1': '',
#     'StreetAddress2': '',
#     'City': '',
#     'State': '',
#     'OtherState': '',
#     'Country': 'USA',
#     'Zip5': '',
#     'Zip4': '',
#     'PostalCode': '',
#     'County': None,
#     'CountyName': None,
#     'CountryName': 'UNITED STATES'},
#    'IsSameAsMailingAddress': False,
#    'IsSameAsAgentAddress': False,
#    'BusinessID': 1537697,
#    'Status': None,
#    'MemberOrManager': 0,
#    'IsPrincipalOfficeNotInWa': False,
#    'IsFormation': False,
#    'IsNotRequired': False,
#    'IsACP': False,
#    'ParticipantNumber': None,
#    'IsForNonProfitAmendment': False,
#    'IsOldDataExist': True,
#    'FilerID': 0,
#    'UserID': 0,
#    'CreatedBy': 0,
#    'IPAddress': None,
#    'ModifiedBy': 0,
#    'ModifiedIPAddress': None}],
#  'PrincipalName': None,
#  'SearchCriteria': None,
#  'SearchType': None,
#  'SearchTypeText': None,
#  'SearchValue': None,
#  'SearchEntityName': None,
#  'StartDateOfIncorporation': '0001-01-01T00:00:00',
#  'EndDateOfIncorporation': '0001-01-01T00:00:00',
#  'ExpirationDate': '0001-01-01T00:00:00',
#  'Criteria': None,
#  'GrangeAddress': {'Attention': None,
#   'NotificationAttention': None,
#   'CorrespondenceEmailAddress': None,
#   'ConsolidationCorrespondenceEmailAddress': None,
#   'ZipExtension': None,
#   'AddressEntityType': None,
#   'IsAddressSame': False,
#   'isUserNonCommercialRegisteredAgent': False,
#   'baseEntity': {'FilerID': 0,
#    'UserID': 0,
#    'CreatedBy': 0,
#    'IPAddress': None,
#    'ModifiedBy': 0,
#    'ModifiedIPAddress': None},
#   'IsInvalidState': False,
#   'IsAgentInWA': None,
#   'isRAStreetAddressValid': False,
#   'IsAddressReturnedMail': False,
#   'FullAddress': '',
#   'ID': 0,
#   'StreetAddress1': '',
#   'StreetAddress2': '',
#   'City': '',
#   'State': '',
#   'OtherState': '',
#   'Country': '',
#   'Zip5': '',
#   'Zip4': '',
#   'PostalCode': '',
#   'County': None,
#   'CountyName': None,
#   'CountryName': ''},
#  'MeetingPlace': {'Attention': None,
#   'NotificationAttention': None,
#   'CorrespondenceEmailAddress': None,
#   'ConsolidationCorrespondenceEmailAddress': None,
#   'ZipExtension': None,
#   'AddressEntityType': None,
#   'IsAddressSame': False,
#   'isUserNonCommercialRegisteredAgent': False,
#   'baseEntity': {'FilerID': 0,
#    'UserID': 0,
#    'CreatedBy': 0,
#    'IPAddress': None,
#    'ModifiedBy': 0,
#    'ModifiedIPAddress': None},
#   'IsInvalidState': False,
#   'IsAgentInWA': None,
#   'isRAStreetAddressValid': False,
#   'IsAddressReturnedMail': False,
#   'FullAddress': '11010 NE 8TH ST STE 465, BELLEVUE, WA, 98004-4408, UNITED STATES',
#   'ID': 2668350,
#   'StreetAddress1': '11010 NE 8TH ST STE 465',
#   'StreetAddress2': '',
#   'City': 'BELLEVUE',
#   'State': 'WA',
#   'OtherState': '',
#   'Country': 'USA',
#   'Zip5': '98004',
#   'Zip4': '4408',
#   'PostalCode': '',
#   'County': None,
#   'CountyName': None,
#   'CountryName': 'UNITED STATES'},
#  'IsOrgBusinessName': False,
#  'CheckBusinessName': None,
#  'PlusOrMinusOrder': 0,
#  'FiltereRecordId': 0,
#  'ModifiedDate': '0001-01-01T00:00:00',
#  'DissolutionDays': 0,
#  'ID': 0,
#  'isInhouse': False,
#  'FeeList': None,
#  'UBIStatus': None,
#  'IsUbiNumber': False,
#  'NewUBINumber': None,
#  'IsShowAdvanceSearch': False,
#  'EntityName': None,
#  'Status': None,
#  'Type': None,
#  'IsHostHomeSearch': None,
#  'IsPublicBenefitNonProfitSearch': None,
#  'IsCharitableNonProfitSearch': None,
#  'IsGrossRevenueNonProfitSearch': None,
#  'IsHasMembersSearch': None,
#  'IsHasFEINSearch': None,
#  'FEINNoSearch': None,
#  'IsHostHome': False,
#  'IsPublicBenefitNonProfit': False,
#  'IsCharitableNonProfit': False,
#  'IsGrossRevenueNonProfit': False,
#  'IsHasMembers': None,
#  'IsHasFEIN': None,
#  'EntityTypesWithScreens': {},
#  'AllScreenParts': {},
#  'OnlineReportPrincipalList': None,
#  'OnlineUploadDocumentsList': [],
#  'UploadDocumentsList': [],
#  'PrincipalMemberList': [],
#  'CorrespondenceAddress': {'Attention': None,
#   'NotificationAttention': None,
#   'CorrespondenceEmailAddress': None,
#   'ConsolidationCorrespondenceEmailAddress': None,
#   'ZipExtension': None,
#   'AddressEntityType': None,
#   'IsAddressSame': False,
#   'isUserNonCommercialRegisteredAgent': False,
#   'baseEntity': {'FilerID': 0,
#    'UserID': 0,
#    'CreatedBy': 0,
#    'IPAddress': None,
#    'ModifiedBy': 0,
#    'ModifiedIPAddress': None},
#   'IsInvalidState': False,
#   'IsAgentInWA': None,
#   'isRAStreetAddressValid': False,
#   'IsAddressReturnedMail': False,
#   'FullAddress': '',
#   'ID': 0,
#   'StreetAddress1': None,
#   'StreetAddress2': None,
#   'City': None,
#   'State': None,
#   'OtherState': None,
#   'Country': None,
#   'Zip5': None,
#   'Zip4': None,
#   'PostalCode': None,
#   'County': None,
#   'CountyName': None,
#   'CountryName': ''},
#  'OnlineReportAgent': {'Type': None,
#   'AgentID': 0,
#   'EntityName': None,
#   'OrganizationName': None,
#   'FirstName': None,
#   'LastName': None,
#   'IsNonCommercial': False,
#   'EmailAddress': None,
#   'AgentTypeID': 0,
#   'StreetAddress': {'Attention': None,
#    'NotificationAttention': None,
#    'CorrespondenceEmailAddress': None,
#    'ConsolidationCorrespondenceEmailAddress': None,
#    'ZipExtension': None,
#    'AddressEntityType': None,
#    'IsAddressSame': False,
#    'isUserNonCommercialRegisteredAgent': False,
#    'baseEntity': {'FilerID': 0,
#     'UserID': 0,
#     'CreatedBy': 0,
#     'IPAddress': None,
#     'ModifiedBy': 0,
#     'ModifiedIPAddress': None},
#    'IsInvalidState': False,
#    'IsAgentInWA': None,
#    'isRAStreetAddressValid': False,
#    'IsAddressReturnedMail': False,
#    'FullAddress': '',
#    'ID': 0,
#    'StreetAddress1': None,
#    'StreetAddress2': None,
#    'City': None,
#    'State': None,
#    'OtherState': None,
#    'Country': None,
#    'Zip5': None,
#    'Zip4': None,
#    'PostalCode': None,
#    'County': None,
#    'CountyName': None,
#    'CountryName': ''},
#   'MailingAddress': {'Attention': None,
#    'NotificationAttention': None,
#    'CorrespondenceEmailAddress': None,
#    'ConsolidationCorrespondenceEmailAddress': None,
#    'ZipExtension': None,
#    'AddressEntityType': None,
#    'IsAddressSame': False,
#    'isUserNonCommercialRegisteredAgent': False,
#    'baseEntity': {'FilerID': 0,
#     'UserID': 0,
#     'CreatedBy': 0,
#     'IPAddress': None,
#     'ModifiedBy': 0,
#     'ModifiedIPAddress': None},
#    'IsInvalidState': False,
#    'IsAgentInWA': None,
#    'isRAStreetAddressValid': False,
#    'IsAddressReturnedMail': False,
#    'FullAddress': '',
#    'ID': 0,
#    'StreetAddress1': None,
#    'StreetAddress2': None,
#    'City': None,
#    'State': None,
#    'OtherState': None,
#    'Country': None,
#    'Zip5': None,
#    'Zip4': None,
#    'PostalCode': None,
#    'County': None,
#    'CountyName': None,
#    'CountryName': ''},
#   'IsUserRegisteredAgent': False,
#   'PhoneNumber': None,
#   'IsRegisteredAgentConsent': False,
#   'Title': None,
#   'IsSameAsMailingAddress': False,
#   'CreatedBy': None,
#   'AgentCreatdDate': None,
#   'AgentCreatdIP': None,
#   'IsNewAgent': False,
#   'TotalCount': 0,
#   'IsAgentConsentShow': False,
#   'IsAgentChange': False,
#   'IsAgentFormation': False,
#   'OfficeOrPosition': None,
#   'BusinessIDForRA': 0,
#   'BusinessAgentAddressID': 0,
#   'BusinessAgentMailingAddressID': 0,
#   'IsAgentEdit': False,
#   'IsAgentAltered': False,
#   'IsOnlineAgent': False,
#   'Criteria': None,
#   'AgentStreet1': None,
#   'AgentStreet2': None,
#   'City': None,
#   'State': None,
#   'OtherState': None,
#   'PostalCode': None,
#   'Country': None,
#   'Zip4': None,
#   'Zip5': None,
#   'BusinessTypeID': 0,
#   'BusinessType': None,
#   'Jurisdiction': 0,
#   'JurisdictionDesc': None,
#   'JurisdictionState': 0,
#   'JurisdictionCountry': 0,
#   'JurisdictionStateDesc': None,
#   'JurisdictionCountryDesc': None,
#   'JurisdictionCategory': None,
#   'IsCRARegistration': False,
#   'IsCRAAttestation': False,
#   'IsCRANotification': False,
#   'IsCRAStatementofChanged': False,
#   'IsRepresentedAttestation': False,
#   'OldEntityName': None,
#   'OldFirstName': None,
#   'OldLastName': None,
#   'isStreetStateMustbeinWA': False,
#   'isMailingStateMustbeinWA': False,
#   'isRAAddressValid': False,
#   'IsAmendmentAgentInfoChange': False,
#   'IsRAOfficeorPositionSearch': False,
#   'FullName': '',
#   'AgentType': None,
#   'IsACP': False,
#   'ParticipantNumber': None},
#  'TrademarkOwnerAgent': {'Type': None,
#   'AgentID': 0,
#   'EntityName': None,
#   'OrganizationName': None,
#   'FirstName': None,
#   'LastName': None,
#   'IsNonCommercial': False,
#   'EmailAddress': None,
#   'AgentTypeID': 0,
#   'StreetAddress': {'Attention': None,
#    'NotificationAttention': None,
#    'CorrespondenceEmailAddress': None,
#    'ConsolidationCorrespondenceEmailAddress': None,
#    'ZipExtension': None,
#    'AddressEntityType': None,
#    'IsAddressSame': False,
#    'isUserNonCommercialRegisteredAgent': False,
#    'baseEntity': {'FilerID': 0,
#     'UserID': 0,
#     'CreatedBy': 0,
#     'IPAddress': None,
#     'ModifiedBy': 0,
#     'ModifiedIPAddress': None},
#    'IsInvalidState': False,
#    'IsAgentInWA': None,
#    'isRAStreetAddressValid': False,
#    'IsAddressReturnedMail': False,
#    'FullAddress': '',
#    'ID': 0,
#    'StreetAddress1': None,
#    'StreetAddress2': None,
#    'City': None,
#    'State': None,
#    'OtherState': None,
#    'Country': None,
#    'Zip5': None,
#    'Zip4': None,
#    'PostalCode': None,
#    'County': None,
#    'CountyName': None,
#    'CountryName': ''},
#   'MailingAddress': {'Attention': None,
#    'NotificationAttention': None,
#    'CorrespondenceEmailAddress': None,
#    'ConsolidationCorrespondenceEmailAddress': None,
#    'ZipExtension': None,
#    'AddressEntityType': None,
#    'IsAddressSame': False,
#    'isUserNonCommercialRegisteredAgent': False,
#    'baseEntity': {'FilerID': 0,
#     'UserID': 0,
#     'CreatedBy': 0,
#     'IPAddress': None,
#     'ModifiedBy': 0,
#     'ModifiedIPAddress': None},
#    'IsInvalidState': False,
#    'IsAgentInWA': None,
#    'isRAStreetAddressValid': False,
#    'IsAddressReturnedMail': False,
#    'FullAddress': '',
#    'ID': 0,
#    'StreetAddress1': None,
#    'StreetAddress2': None,
#    'City': None,
#    'State': None,
#    'OtherState': None,
#    'Country': None,
#    'Zip5': None,
#    'Zip4': None,
#    'PostalCode': None,
#    'County': None,
#    'CountyName': None,
#    'CountryName': ''},
#   'IsUserRegisteredAgent': False,
#   'PhoneNumber': None,
#   'IsRegisteredAgentConsent': False,
#   'Title': None,
#   'IsSameAsMailingAddress': False,
#   'CreatedBy': None,
#   'AgentCreatdDate': None,
#   'AgentCreatdIP': None,
#   'IsNewAgent': False,
#   'TotalCount': 0,
#   'IsAgentConsentShow': False,
#   'IsAgentChange': False,
#   'IsAgentFormation': False,
#   'OfficeOrPosition': None,
#   'BusinessIDForRA': 0,
#   'BusinessAgentAddressID': 0,
#   'BusinessAgentMailingAddressID': 0,
#   'IsAgentEdit': False,
#   'IsAgentAltered': False,
#   'IsOnlineAgent': False,
#   'Criteria': None,
#   'AgentStreet1': None,
#   'AgentStreet2': None,
#   'City': None,
#   'State': None,
#   'OtherState': None,
#   'PostalCode': None,
#   'Country': None,
#   'Zip4': None,
#   'Zip5': None,
#   'BusinessTypeID': 0,
#   'BusinessType': None,
#   'Jurisdiction': 0,
#   'JurisdictionDesc': None,
#   'JurisdictionState': 0,
#   'JurisdictionCountry': 0,
#   'JurisdictionStateDesc': None,
#   'JurisdictionCountryDesc': None,
#   'JurisdictionCategory': None,
#   'IsCRARegistration': False,
#   'IsCRAAttestation': False,
#   'IsCRANotification': False,
#   'IsCRAStatementofChanged': False,
#   'IsRepresentedAttestation': False,
#   'OldEntityName': None,
#   'OldFirstName': None,
#   'OldLastName': None,
#   'isStreetStateMustbeinWA': False,
#   'isMailingStateMustbeinWA': False,
#   'isRAAddressValid': False,
#   'IsAmendmentAgentInfoChange': False,
#   'IsRAOfficeorPositionSearch': False,
#   'FullName': '',
#   'AgentType': None,
#   'IsACP': False,
#   'ParticipantNumber': None},
#  'OnlineReportAuthorizedPerson': {'AuthorizedPersonFirstName': None,
#   'AuthorizedPersonLastName': None,
#   'AuthorizedPersonTitle': None,
#   'AuthorizedPersonEntityName': None,
#   'IsAccepted': False,
#   'DocUnderPenalities': None,
#   'DocIsSigned': False,
#   'IsRAorTrusteeCoverSheetSigned': False,
#   'IsTrustreeSignedTrustAgreement': False,
#   'PersonType': None,
#   'IsRequired': False,
#   'AuthorizerName': None,
#   'ErrorMsgs': None,
#   'InhouseReviewHTML': None,
#   'InhouseInitialReportReviewHTML': None},
#  'OnlineReportBusinessTransaction': None,
#  'ARDueDate': '2023-02-28T00:00:00',
#  'createdDate': '0001-01-01T00:00:00',
#  'DateBeganDoingBusinessInWA': '0001-01-01T00:00:00',
#  'DateOfAdoption': '0001-01-01T00:00:00',
#  'DateOfFormationInHomeJurisdiction': '0001-01-01T00:00:00',
#  'DateOfIncorporation': '2022-02-18T00:00:00',
#  'DissolvedDate': '0001-01-01T00:00:00',
#  'EffectiveDate': '0001-01-01T00:00:00',
#  'ExpirationDateReview': '0001-01-01T00:00:00',
#  'FilingDate': '0001-01-01T00:00:00',
#  'NextARDueDate': '2024-02-28T00:00:00',
#  'PeriodofDurationDate': '0001-01-01T00:00:00',
#  'RAExpiredDate': '0001-01-01T00:00:00',
#  'ReinstatementDissolutionEndDate': '0001-01-01T00:00:00',
#  'RenewalDate': '0001-01-01T00:00:00',
#  'RequalificationTerminationEndDate': '0001-01-01T00:00:00',
#  'DurationExpireDate': '0001-01-01T00:00:00',
#  'InActiveDate': '0001-01-01T00:00:00',
#  'LastARFiledDate': '2023-02-28T00:00:00',
#  'NameReservationExpireDate': None,
#  'PeriodofDurationDateReview': '0001-01-01T00:00:00',
#  'OnlineReportNatureOfBusiness': None,
#  'OnlineCartEntity': None,
#  'BusinessInfoPrincipalOffice': {'PrincipalID': 0,
#   'SequenceNo': 0,
#   'FirstName': None,
#   'LastName': None,
#   'FullName': None,
#   'Title': None,
#   'Name': None,
#   'MiddleName': None,
#   'PhoneNumber': '',
#   'EmailAddress': 'INFO@CHANGLAWGROUP.COM',
#   'TypeID': None,
#   'PrincipalBaseType': None,
#   'PrincipalMailingAddress': {'Attention': None,
#    'NotificationAttention': None,
#    'CorrespondenceEmailAddress': None,
#    'ConsolidationCorrespondenceEmailAddress': None,
#    'ZipExtension': None,
#    'AddressEntityType': None,
#    'IsAddressSame': False,
#    'isUserNonCommercialRegisteredAgent': False,
#    'baseEntity': {'FilerID': 0,
#     'UserID': 0,
#     'CreatedBy': 0,
#     'IPAddress': None,
#     'ModifiedBy': 0,
#     'ModifiedIPAddress': None},
#    'IsInvalidState': False,
#    'IsAgentInWA': None,
#    'isRAStreetAddressValid': False,
#    'IsAddressReturnedMail': False,
#    'FullAddress': '11010 NE 8TH ST STE 465, BELLEVUE, WA, 98004-4408, UNITED STATES',
#    'ID': 2668350,
#    'StreetAddress1': '11010 NE 8TH ST STE 465',
#    'StreetAddress2': '',
#    'City': 'BELLEVUE',
#    'State': 'WA',
#    'OtherState': '',
#    'Country': 'USA',
#    'Zip5': '98004',
#    'Zip4': '4408',
#    'PostalCode': '',
#    'County': None,
#    'CountyName': None,
#    'CountryName': 'UNITED STATES'},
#   'PrincipalStreetAddress': {'Attention': None,
#    'NotificationAttention': None,
#    'CorrespondenceEmailAddress': None,
#    'ConsolidationCorrespondenceEmailAddress': None,
#    'ZipExtension': None,
#    'AddressEntityType': None,
#    'IsAddressSame': False,
#    'isUserNonCommercialRegisteredAgent': False,
#    'baseEntity': {'FilerID': 0,
#     'UserID': 0,
#     'CreatedBy': 0,
#     'IPAddress': None,
#     'ModifiedBy': 0,
#     'ModifiedIPAddress': None},
#    'IsInvalidState': False,
#    'IsAgentInWA': None,
#    'isRAStreetAddressValid': False,
#    'IsAddressReturnedMail': False,
#    'FullAddress': '11010 NE 8TH ST STE 465, BELLEVUE, WA, 98004-4408, UNITED STATES',
#    'ID': 2668349,
#    'StreetAddress1': '11010 NE 8TH ST STE 465',
#    'StreetAddress2': '',
#    'City': 'BELLEVUE',
#    'State': 'WA',
#    'OtherState': '',
#    'Country': 'USA',
#    'Zip5': '98004',
#    'Zip4': '4408',
#    'PostalCode': '',
#    'County': None,
#    'CountyName': None,
#    'CountryName': 'UNITED STATES'},
#   'IsSameAsMailingAddress': False,
#   'IsSameAsAgentAddress': False,
#   'BusinessID': 0,
#   'Status': None,
#   'MemberOrManager': 0,
#   'IsPrincipalOfficeNotInWa': False,
#   'IsFormation': False,
#   'IsNotRequired': False,
#   'IsACP': False,
#   'ParticipantNumber': None,
#   'IsForNonProfitAmendment': False,
#   'IsOldDataExist': True,
#   'FilerID': 0,
#   'UserID': 0,
#   'CreatedBy': 0,
#   'IPAddress': None,
#   'ModifiedBy': 0,
#   'ModifiedIPAddress': None},
#  'BusinessInfoPrincipalOfficeInWA': {'PrincipalID': 0,
#   'SequenceNo': 0,
#   'FirstName': None,
#   'LastName': None,
#   'FullName': None,
#   'Title': None,
#   'Name': None,
#   'MiddleName': None,
#   'PhoneNumber': None,
#   'EmailAddress': None,
#   'TypeID': None,
#   'PrincipalBaseType': None,
#   'PrincipalMailingAddress': {'Attention': None,
#    'NotificationAttention': None,
#    'CorrespondenceEmailAddress': None,
#    'ConsolidationCorrespondenceEmailAddress': None,
#    'ZipExtension': None,
#    'AddressEntityType': None,
#    'IsAddressSame': False,
#    'isUserNonCommercialRegisteredAgent': False,
#    'baseEntity': {'FilerID': 0,
#     'UserID': 0,
#     'CreatedBy': 0,
#     'IPAddress': None,
#     'ModifiedBy': 0,
#     'ModifiedIPAddress': None},
#    'IsInvalidState': False,
#    'IsAgentInWA': None,
#    'isRAStreetAddressValid': False,
#    'IsAddressReturnedMail': False,
#    'FullAddress': '',
#    'ID': 0,
#    'StreetAddress1': None,
#    'StreetAddress2': None,
#    'City': None,
#    'State': None,
#    'OtherState': None,
#    'Country': None,
#    'Zip5': None,
#    'Zip4': None,
#    'PostalCode': None,
#    'County': None,
#    'CountyName': None,
#    'CountryName': ''},
#   'PrincipalStreetAddress': {'Attention': None,
#    'NotificationAttention': None,
#    'CorrespondenceEmailAddress': None,
#    'ConsolidationCorrespondenceEmailAddress': None,
#    'ZipExtension': None,
#    'AddressEntityType': None,
#    'IsAddressSame': False,
#    'isUserNonCommercialRegisteredAgent': False,
#    'baseEntity': {'FilerID': 0,
#     'UserID': 0,
#     'CreatedBy': 0,
#     'IPAddress': None,
#     'ModifiedBy': 0,
#     'ModifiedIPAddress': None},
#    'IsInvalidState': False,
#    'IsAgentInWA': None,
#    'isRAStreetAddressValid': False,
#    'IsAddressReturnedMail': False,
#    'FullAddress': '',
#    'ID': 0,
#    'StreetAddress1': None,
#    'StreetAddress2': None,
#    'City': None,
#    'State': None,
#    'OtherState': None,
#    'Country': None,
#    'Zip5': None,
#    'Zip4': None,
#    'PostalCode': None,
#    'County': None,
#    'CountyName': None,
#    'CountryName': ''},
#   'IsSameAsMailingAddress': False,
#   'IsSameAsAgentAddress': False,
#   'BusinessID': 0,
#   'Status': None,
#   'MemberOrManager': 0,
#   'IsPrincipalOfficeNotInWa': False,
#   'IsFormation': False,
#   'IsNotRequired': False,
#   'IsACP': False,
#   'ParticipantNumber': None,
#   'IsForNonProfitAmendment': False,
#   'IsOldDataExist': False,
#   'FilerID': 0,
#   'UserID': 0,
#   'CreatedBy': 0,
#   'IPAddress': None,
#   'ModifiedBy': 0,
#   'ModifiedIPAddress': None},
#  'OnlineReportPrincipalOffice': {'PrincipalID': 0,
#   'SequenceNo': 0,
#   'FirstName': None,
#   'LastName': None,
#   'FullName': None,
#   'Title': None,
#   'Name': None,
#   'MiddleName': None,
#   'PhoneNumber': None,
#   'EmailAddress': None,
#   'TypeID': None,
#   'PrincipalBaseType': None,
#   'PrincipalMailingAddress': {'Attention': None,
#    'NotificationAttention': None,
#    'CorrespondenceEmailAddress': None,
#    'ConsolidationCorrespondenceEmailAddress': None,
#    'ZipExtension': None,
#    'AddressEntityType': None,
#    'IsAddressSame': False,
#    'isUserNonCommercialRegisteredAgent': False,
#    'baseEntity': {'FilerID': 0,
#     'UserID': 0,
#     'CreatedBy': 0,
#     'IPAddress': None,
#     'ModifiedBy': 0,
#     'ModifiedIPAddress': None},
#    'IsInvalidState': False,
#    'IsAgentInWA': None,
#    'isRAStreetAddressValid': False,
#    'IsAddressReturnedMail': False,
#    'FullAddress': '',
#    'ID': 0,
#    'StreetAddress1': None,
#    'StreetAddress2': None,
#    'City': None,
#    'State': None,
#    'OtherState': None,
#    'Country': None,
#    'Zip5': None,
#    'Zip4': None,
#    'PostalCode': None,
#    'County': None,
#    'CountyName': None,
#    'CountryName': ''},
#   'PrincipalStreetAddress': {'Attention': None,
#    'NotificationAttention': None,
#    'CorrespondenceEmailAddress': None,
#    'ConsolidationCorrespondenceEmailAddress': None,
#    'ZipExtension': None,
#    'AddressEntityType': None,
#    'IsAddressSame': False,
#    'isUserNonCommercialRegisteredAgent': False,
#    'baseEntity': {'FilerID': 0,
#     'UserID': 0,
#     'CreatedBy': 0,
#     'IPAddress': None,
#     'ModifiedBy': 0,
#     'ModifiedIPAddress': None},
#    'IsInvalidState': False,
#    'IsAgentInWA': None,
#    'isRAStreetAddressValid': False,
#    'IsAddressReturnedMail': False,
#    'FullAddress': '',
#    'ID': 0,
#    'StreetAddress1': None,
#    'StreetAddress2': None,
#    'City': None,
#    'State': None,
#    'OtherState': None,
#    'Country': None,
#    'Zip5': None,
#    'Zip4': None,
#    'PostalCode': None,
#    'County': None,
#    'CountyName': None,
#    'CountryName': ''},
#   'IsSameAsMailingAddress': False,
#   'IsSameAsAgentAddress': False,
#   'BusinessID': 0,
#   'Status': None,
#   'MemberOrManager': 0,
#   'IsPrincipalOfficeNotInWa': False,
#   'IsFormation': False,
#   'IsNotRequired': False,
#   'IsACP': False,
#   'ParticipantNumber': None,
#   'IsForNonProfitAmendment': False,
#   'IsOldDataExist': False,
#   'FilerID': 0,
#   'UserID': 0,
#   'CreatedBy': 0,
#   'IPAddress': None,
#   'ModifiedBy': 0,
#   'ModifiedIPAddress': None},
#  'UploadDocuments': {'FileName': None,
#   'FileLocation': None,
#   'TempFileName': None,
#   'TempFileLocation': None,
#   'DocumentTypeId': 0,
#   'DocumentType': None,
#   'BusinessId': 0,
#   'BusinessFilingDocumentId': 0,
#   'FilingNo': 0,
#   'CreatedBy': 0,
#   'Status': None,
#   'TransactionID': 0,
#   'UploadFileName': None,
#   'IsPublicVisible': False,
#   'NumberOfPages': 0,
#   'FilingDateTime': '0001-01-01T00:00:00',
#   'Source': None,
#   'UserName': None,
#   'IsOnline': False,
#   'CartId': 0,
#   'UploadDocumentID': 0,
#   'DocumentTable': None,
#   'DocumentID': 0},
#  'OSOSCorpSignatureBlockEmail': None,
#  'OSOSCorpEmailSignature': None,
#  'OSOSCharitiesSignatureBlockEmail': None,
#  'BIIsOtherNAICS': False,
#  'BusinessHasActiveFilings': False,
#  'DisableFEIN': False,
#  'DisableUBI': False,
#  'EffectiveDateFlag': False,
#  'FilingSuccess': False,
#  'IsActiveFilingExist': False,
#  'IsAdditionalDocumentsExist': False,
#  'IsAgentEditShow': False,
#  'IsAgentMailingAddressReturnedMail': False,
#  'IsAgentStreetAddressReturnedMail': False,
#  'IsAmendmentAdoptionChange': False,
#  'IsAmendmentCorpSharesChange': False,
#  'IsAmendmentDelinquentStatus': False,
#  'IsAmendmentDurationChange': False,
#  'IsAmendmentEffectiveChange': False,
#  'IsAmendmentEntityNameChange': False,
#  'IsAmendmentEntityType': False,
#  'IsAmendmentPeriodofDuration': False,
#  'IsApplicantAddressReturnedMail': False,
#  'IsBatchJobSchedule': False,
#  'IsBusinessHide': False,
#  'isBusinessNameAvailable': False,
#  'IsCertificateofExistence': False,
#  'IsCertificateOfExistencePresent': False,
#  'IsCharitable': False,
#  'IsClientAddressReturnedMail': False,
#  'IsConsildationInCorp': False,
#  'IsCorrespondenceAddress': False,
#  'IsDBAInUse': False,
#  'isDBANameAvailable': False,
#  'IsDBASectionExist': False,
#  'IsDomesticUBI': False,
#  'IsEligibleFilingType': False,
#  'IsEmailOptionChecked': False,
#  'IsEmailOptionHide': False,
#  'IsFormation': False,
#  'IsFormationWithIntialReport': False,
#  'IsGrangeAddressReturnedMail': False,
#  'IsInhouseReviewOrFiling': False,
#  'IsInitialReportFiled': False,
#  'IsMeetingAddressReturnedMail': False,
#  'IsNameReserved': False,
#  'IsOnline': False,
#  'IsPerpetual': False,
#  'IsPOMailingAddressReturnedMail': False,
#  'IsPOStreetAddressReturnedMail': False,
#  'IsRALookupEnabled': False,
#  'IsReveiwPDFFieldsShow': False,
#  'IsSaveCloseWithInitialReport': False,
#  'IsTMApplicantAddressReturnedMail': False,
#  'IsTMOwnerAddressReturnedMail': False,
#  'isTradeMarkHide': False,
#  'IsTrademarkApplicantAddress': False,
#  'IsTrademarkOwnerAddress': False,
#  'IsTransactionFulfilled': False,
#  'IsUnansweredOrBlank': False,
#  'IsUploadDocumentExist': False,
#  'IsWalkInClose': False,
#  'IsWalkInSave': False,
#  'OnlineIsUBIChecked': False,
#  'validateUbiNumber': False,
#  'IsDORQuestionProperty': False,
#  'IsDORQuestionInterest16': False,
#  'IsDORQuestionInterest50': False,
#  'IsDORQuestionFuturePurchase': False,
#  'IsNewDORQuestionsAnswered': False,
#  'actionName': None,
#  'AgentId': 0,
#  'AgentName': None,
#  'AlternativeEmail': None,
#  'AmendedBusinessType': 0,
#  'AmendedBusinessTypeDesc': None,
#  'AnyOtherProvisions': None,
#  'Attention': None,
#  'AvailableStatus': None,
#  'BINAICSCode': '6',
#  'BINAICSCodeDesc': ' Lodging',
#  'BIOtherDescription': '',
#  'BusinessCategoryID': 0,
#  'BusinessCategory': 'FOREIGN ENTITY',
#  'BusinessID': 1537697,
#  'BusinessIDs': None,
#  'BusinessIndicator': None,
#  'BusinessName': 'TMUD GSL, LLC',
#  'BusinessStatus': 'Active',
#  'BusinessStatusID': 1,
#  'BusinessNameSearch': None,
#  'BusinessPartnershipEngages': None,
#  'BusinessType': 'FOREIGN LIMITED LIABILITY COMPANY',
#  'BusinessTypeID': 20,
#  'CartStatus': None,
#  'ConfirmationLetterDocumentID': 0,
#  'ConfirmationLetterFileName': None,
#  'CongratulationLetterFileName': None,
#  'controllerName': None,
#  'CorrespondenceEmailAddress': None,
#  'CorrespondenceFileName': None,
#  'createdBy': 0,
#  'createdIP': None,
#  'DateBeganDoingBusinessInWAType': None,
#  'DateOfAdoptionType': None,
#  'DBABusinessName': '',
#  'DocumentID': 0,
#  'DocumentTypeID': 0,
#  'DurationType': None,
#  'DurationYears': 0,
#  'EffectiveDateType': None,
#  'FileLocationOnlineInitialReport': None,
#  'FileLocationConfirmationLetter': None,
#  'FEINNo': '',
#  'FilingCorrespondenceAddressFileLocation': None,
#  'FilingCorrespondenceAddressFileName': None,
#  'FileLocationCongratulationLetter': None,
#  'FileLocationCorrespondence': None,
#  'FileLocationOnlineReport': None,
#  'FileLocationReceipt': None,
#  'InitialReportReviewHTML': None,
#  'IsAnnualReportFiledCount': 0,
#  'IsFeeWaiverFullFilledCount': 0,
#  'Jurisdiction': 64,
#  'JurisdictionCategory': 'S',
#  'JurisdictionCategoryReview': 'S',
#  'JurisdictionCountry': 261,
#  'JurisdictionCountryDesc': None,
#  'JurisdictionCountryDescReview': None,
#  'JurisdictionCountryReview': 261,
#  'JurisdictionDesc': 'DELAWARE',
#  'JurisdictionDescReview': 'DELAWARE',
#  'JurisdictionReview': 64,
#  'JurisdictionState': 64,
#  'JurisdictionStateDesc': None,
#  'JurisdictionStateDescReview': None,
#  'JurisdictionStateReview': 64,
#  'NewBusinessName': None,
#  'NewDBABusinessName': None,
#  'NameInHomeJurisdiction': None,
#  'NameReservedId': 0,
#  'NavigateUrl': None,
#  'NewBusinessStatusID': 0,
#  'NewFilingHistory': None,
#  'NewNameInHomeJurisdiction': None,
#  'NotificationAttention': None,
#  'OldBusinessName': None,
#  'OldDBABusinessName': None,
#  'OldFilingHistory': None,
#  'OldJurisdictionDesc': None,
#  'OnlineCartDraftID': 0,
#  'OnlineInitialReportFileName': None,
#  'OnlineInitialReportDocumentID': 0,
#  'OnlineLookupUBINo': None,
#  'OnlineNavigationUrl': None,
#  'OnlineReportDocumentID': 0,
#  'OnlineReportFileName': None,
#  'OtherProvisions': None,
#  'PlaceofFormationId': None,
#  'PurposeAndPowersID': 0,
#  'ReviewHTML': None,
#  'ReceiptFileName': None,
#  'ReprortAgentFullAddress': None,
#  'ReprortCorrespondenceFullAddress': None,
#  'ReprortFullAddress': None,
#  'SaveCloseExceptionCount': 0,
#  'SaveCloseNotesCount': 0,
#  'SeqNumber': 0,
#  'TempTableID': 0,
#  'TrademarkEnityName': None,
#  'TrademarkOwnerEntityName': None,
#  'TrademarkOwnerAddressFileName': None,
#  'TrademarkOwnerAddressFileNameLocation': None,
#  'TrademarkOwnerFullName': None,
#  'TrademarkOwnerFullAddress': None,
#  'TrademarkOwnerFirstName': None,
#  'TrademarkOwnerLastName': None,
#  'UBIBusinessType': None,
#  'UBIBusinessTypeID': 0,
#  'UBINumber': '604 874 529',
#  'HasMemberNonProfit': False,
#  'HasIncorporator': None,
#  'HasBoardOfDirectors': None,
#  'IsCanBePublicBenefitNonProfit': None,
#  'IsElectToBePublicBenefitNonProfit': None,
#  'IsRCWElection': None,
#  'IsNonProfitExempt': None,
#  'IsCanBeHostHome': None,
#  'NonProfitReporting1': None,
#  'NonProfitReporting2': None,
#  'IsAmendmentDeliquentStatus': False,
#  'IsIncorporatorSignatureAttestation': None,
#  'ExistingIsRCWElection': None,
#  'ExistingIsIncorporatorSignatureAttestation': None,
#  'ExistingIsCharitableNonProfit': False,
#  'ExistingIsHostHome': False,
#  'ExistingIsGrossRevenueNonProfit': True,
#  'ExistingIsPublicBenefitNonProfit': False,
#  'ExistingHasMemberNonProfit': False,
#  'ExistingFEINNo': '',
#  'IsHideBusinessInformationNPCheckboxes': False}

# %%
def extract_principals(business_res):
    agent = business_res['Agent']['EntityName']
    rows = [[
        # name of company?
        agent,
        'Entity' if principal['TypeID'] == 'E' else 'Individual',
        principal['PrincipalID'],
         principal['Name'] if principal['TypeID'] == 'E' else principal['FirstName'] + ' ' + principal['LastName']
    ] for principal in business_res['PrincipalsList']]
    return pd.DataFrame(rows, columns=['Agent', 'EntityType', 'PrincipalID', 'PrincipalName'])

e = extract_principals(dets)
e
# Out:
#                 Agent EntityType  PrincipalID    PrincipalName
# 0  CHANG LAW GROUP PC     Entity      3778468  TMUD-IDMGT, LLC

# %%
test_search_term_list = [
'TMUD GSL LLC'
'HH SEATTLE LLC'
'ACORN DEVELOPMENT LLC'
'BRE-BMR 34TH LLC'
'MIDTOWN21 LLC'
'SEATTLE CITY OF'
]

# only give this a list that is unique names and has no "not found" values

def find_potential_matches(search_list):
    for business in search_list:
        search_results = get_business_search_results(business)
        search_df = extract_search_results(business, search results)
        determine_search_matches(search_df)

# %%
how to filter out values as you go?

- start w/ unique owner names
- then when grabbing search results, search for match on id & name & don't search if they match

can you search by address?--no, alas

# %%
# wrong url

# def get_principal_details(principal_id):
#     url = 'https://cfda.sos.wa.gov/api/BusinessSearch/BusinessInformation?principalID={principal_id}'.format(principal_id=principal_id)
#     r = requests.get(url)
#     return json.loads(r.text)

# l = get_principal_details(3778468)
l
# Out:
# {'Message': "No HTTP resource was found that matches the request URI 'https://ccfsinternal.sos.wa.gov:444/api/BusinessSearch/BusinessInformation?principalID=3778468'."}
