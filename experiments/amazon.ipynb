# %%
import numpy as np
import pandas as pd
import geopandas as gp
from shapely.geometry import Polygon, LineString, Point
import matplotlib.pyplot as plt
import util
from scipy import stats
import seaborn as sns

# %% [markdown]
# # 1.0 Preprocessing

# %%
df_districts = gp.read_file("../data/Council_Districts.geojson")
df = pd.read_csv('../data/2020_Building_Energy_Benchmarking.csv')
df = gp.GeoDataFrame(df, geometry=gp.points_from_xy(df.Longitude, df.Latitude))
util.clean_districts(df, df_districts)
# Out:
# Building WATERWORKS OFFICE & MARINA 2353/ 4088803975 doesn't have a district POINT (-122.33895 47.63575)
# 	 Found district 7 for WATERWORKS OFFICE & MARINA
# Building NAUTICAL LANDING 2381/ 4088804350 doesn't have a district POINT (-122.34219 47.64306)
# 	 Found district 7 for NAUTICAL LANDING
# Building UNION HARBOR CONDOMINIUM 2540/ 8807200000 doesn't have a district POINT (-122.33003 47.6401)
# 	 Found district 4 for UNION HARBOR CONDOMINIUM
# Building THE PIER AT LESCHI 2997/ 6780900000 doesn't have a district POINT (-122.28563 47.59926)
# 	 Found district 3 for THE PIER AT LESCHI
# Building THE LAKESHORE 3046/ 1180001715 doesn't have a district POINT EMPTY
# Building EDUCARE 3218/ 2895800030 doesn't have a district POINT EMPTY

# %%
df.columns
# Out:
# Index(['OSEBuildingID', 'DataYear', 'BuildingName', 'BuildingType',
#        'TaxParcelIdentificationNumber', 'Address', 'City', 'State', 'ZipCode',
#        'Latitude', 'Longitude', 'Neighborhood', 'CouncilDistrictCode',
#        'YearBuilt', 'NumberofFloors', 'NumberofBuildings', 'PropertyGFATotal',
#        'PropertyGFABuilding(s)', 'PropertyGFAParking', 'ENERGYSTARScore',
#        'SiteEUIWN(kBtu/sf)', 'SiteEUI(kBtu/sf)', 'SiteEnergyUse(kBtu)',
#        'SiteEnergyUseWN(kBtu)', 'SourceEUIWN(kBtu/sf)', 'SourceEUI(kBtu/sf)',
#        'EPAPropertyType', 'LargestPropertyUseType',
#        'LargestPropertyUseTypeGFA', 'SecondLargestPropertyUseType',
#        'SecondLargestPropertyUseTypeGFA', 'ThirdLargestPropertyUseType',
#        'ThirdLargestPropertyUseTypeGFA', 'Electricity(kWh)', 'SteamUse(kBtu)',
#        'NaturalGas(therms)', 'ComplianceStatus', 'ComplianceIssue',
#        'Electricity(kBtu)', 'NaturalGas(kBtu)', 'TotalGHGEmissions',
#        'GHGEmissionsIntensity', 'geometry'],
#       dtype='object')

# %%
df = df[['OSEBuildingID', 
        'BuildingName', 
        'CouncilDistrictCode', 
        'YearBuilt', 
        'TotalGHGEmissions', 
        'GHGEmissionsIntensity', 
        'EPAPropertyType',
        'geometry']]
df["LegislationBuildingType"] = df['EPAPropertyType'].apply(lambda x: dict_cats.get(x))

# %% [markdown]
# # Data Centers
# - Westin apparently has an agreement with amazon, so it counts
# - "Data Center" is used by AWS, so it counts.

# %%
df[df['LargestPropertyUseType'] == "Data Center"]
# Out:
#       OSEBuildingID  DataYear                           BuildingName  \
# 234             365      2020                   UW TOWER DATA CENTER
# 541             753      2020  THE WESTIN BUILDING EXCHANGE (Office)
# 3165          49780      2020                            DATA CENTER
#
#         BuildingType TaxParcelIdentificationNumber           Address     City  \
# 234   NonResidential                    1142000290  4310 12TH AVE NE  SEATTLE
# 541   NonResidential                    0659000950      2001 6TH AVE  SEATTLE
# 3165  NonResidential                    0659000905      2020 5TH AVE  SEATTLE
#
#      State  ZipCode  Latitude  ...  Electricity(kWh) SteamUse(kBtu)  \
# 234     WA  98105.0  47.66060  ...           9610516              0
# 541     WA  98121.0  47.61438  ...          79296072              0
# 3165    WA  98121.0  47.61449  ...          25004180              0
#
#       NaturalGas(therms)  ComplianceStatus  ComplianceIssue  \
# 234                    0         Compliant         No Issue
# 541                 3157         Compliant         No Issue
# 3165                   0         Compliant         No Issue
#
#       Electricity(kBtu)  NaturalGas(kBtu)  TotalGHGEmissions  \
# 234          32791081.0               0.0              174.4
# 541         270558198.0          315739.0             1455.5
# 3165         85314262.0               0.0              453.7
#
#       GHGEmissionsIntensity                     geometry
# 234                     4.8  POINT (-122.31512 47.66060)
# 541                     3.4  POINT (-122.33871 47.61438)
# 3165                    9.6  POINT (-122.33956 47.61449)
#
# [3 rows x 43 columns]

# %% [markdown]
# # Whole Foods that Amazons owns
# - There's definitely more whole foods than this- investigate
# - Do whole foods show up in different categories (retail?) are they hidden under another name, or just not reported at all?
# - How do whole foods compare to the average in supermarket/grocery store?
# - What's the footprint of whole foods?
#
# The problem is whole foods that are in other bulidings. eg. the cap hill whole foods in
# Need to check second, third most popular use type as well! And figure out a list

# %% [markdown]
# Whole foods:
# - First hill: 1001 Broadway, Seattle, WA 98122 --> the danforth
# - west seattle: 4755 Fauntleroy Way Sw (Ste 190), Seattle, WA 98116 --> the whittaker
# - roosevelt: 1026 Ne 64th Street (at Roosevelt Way NE), Seattle, WA 98115 --> roosevelt square
# - belltown: 2210 Westlake Ave (at Denny Way), Seattle, WA 98121 --> 2200 westlake
# - interbay: 2001 15th Ave W, Seattle, WA 98119 --> whole foods interbay

# %%
df[df['LargestPropertyUseType']=='Supermarket/Grocery Store'].describe()
# Out:
#        OSEBuildingID  DataYear       ZipCode   Latitude   Longitude  \
# count      42.000000      42.0     41.000000  42.000000   42.000000
# mean    20698.952381    2020.0  98120.829268  47.639741 -122.334256
# std     15360.282980       0.0     15.183712   0.059148    0.036118
# min       132.000000    2020.0  98102.000000  47.520950 -122.387300
# 25%       818.250000    2020.0  98109.000000  47.589830 -122.371570
# 50%     22788.500000    2020.0  98118.000000  47.643790 -122.329430
# 75%     26857.750000    2020.0  98125.000000  47.682560 -122.310875
# max     50195.000000    2020.0  98177.000000  47.733150 -122.268250
#
#        CouncilDistrictCode    YearBuilt  NumberofFloors  NumberofBuildings  \
# count            42.000000    42.000000       42.000000          42.000000
# mean              4.214286  1981.119048        1.547619           1.023810
# std               1.994330    23.971734        1.328898           0.154303
# min               1.000000  1916.000000        1.000000           1.000000
# 25%               2.000000  1962.250000        1.000000           1.000000
# 50%               4.000000  1987.500000        1.000000           1.000000
# 75%               6.000000  1999.500000        1.000000           1.000000
# max               7.000000  2016.000000        8.000000           2.000000
#
#        PropertyGFATotal  ...  LargestPropertyUseTypeGFA  \
# count         42.000000  ...                  42.000000
# mean       68231.142857  ...               49862.476190
# std        68062.577110  ...               35347.151672
# min        21603.000000  ...               16000.000000
# 25%        30183.500000  ...               28175.250000
# 50%        45751.000000  ...               41322.500000
# 75%        66752.250000  ...               50639.250000
# max       314958.000000  ...              168735.000000
#
#        SecondLargestPropertyUseTypeGFA  ThirdLargestPropertyUseTypeGFA  \
# count                        23.000000                        5.000000
# mean                      11340.434783                     8518.400000
# std                       19668.251620                    12116.979587
# min                           0.000000                        0.000000
# 25%                           0.000000                     2663.000000
# 50%                           0.000000                     5000.000000
# 75%                       16791.500000                     5055.000000
# max                       72564.000000                    29874.000000
#
#        Electricity(kWh)  SteamUse(kBtu)  NaturalGas(therms)  \
# count      4.200000e+01            42.0           42.000000
# mean       1.667435e+06             0.0        31702.452381
# std        8.966134e+05             0.0        24442.778847
# min        0.000000e+00             0.0            0.000000
# 25%        1.298874e+06             0.0         7153.500000
# 50%        1.491280e+06             0.0        30160.500000
# 75%        2.094161e+06             0.0        53894.750000
# max        4.078974e+06             0.0        85676.000000
#
#        Electricity(kBtu)  NaturalGas(kBtu)  TotalGHGEmissions  \
# count       4.100000e+01      4.100000e+01          41.000000
# mean        5.828053e+06      3.247568e+06         203.468293
# std         2.960408e+06      2.422080e+06         136.781480
# min         4.863550e+05      0.000000e+00           6.900000
# 25%         4.552591e+06      1.091063e+06          71.300000
# 50%         5.088786e+06      3.064567e+06         189.100000
# 75%         7.285985e+06      5.551192e+06         321.100000
# max         1.391746e+07      8.567611e+06         529.000000
#
#        GHGEmissionsIntensity
# count              41.000000
# mean                4.521951
# std                 3.322161
# min                 0.300000
# 25%                 1.500000
# 50%                 4.000000
# 75%                 7.000000
# max                13.200000
#
# [8 rows x 29 columns]

# %%
df[df['BuildingName'].str.contains('whole foods', case=False)]
# Out:
#      OSEBuildingID  DataYear          BuildingName    BuildingType  \
# 497            700      2020  WHOLE FOODS INTERBAY  NonResidential
#
#     TaxParcelIdentificationNumber          Address     City State  ZipCode  \
# 497                    7666201460  2001 15TH AVE W  SEATTLE    WA  98119.0
#
#      Latitude  ...  Electricity(kWh) SteamUse(kBtu)  NaturalGas(therms)  \
# 497  47.63718  ...           1944769              0               48180
#
#      ComplianceStatus  ComplianceIssue  Electricity(kBtu)  NaturalGas(kBtu)  \
# 497         Compliant         No Issue          6635552.0         4818027.0
#
#      TotalGHGEmissions  GHGEmissionsIntensity                     geometry
# 497              291.2                    4.5  POINT (-122.37734 47.63718)
#
# [1 rows x 43 columns]

# %% [markdown]
# # Owned Buildings
# - All buildings with "amazon" in the name
# - Look up all buildings that rent as well as those without "amazon" in the name
# - Look at electricity vs. natural gas breakdown.
# - Look at built date- some are older than expected.
#
# Findings:
# - "amazon" buildings all have pretty good emissions intensity
# - all "amazon" buildings are already compliant. is that a helpful thing?
# - "amazon" buildings are on average more carbon efficient than most office buildings. 0.7 > 0.4 roughly- maybe max boxplot.

# %%
amazon = df[df['BuildingName'].str.contains('amazon', case=False)]
amazon
# Out:
#       OSEBuildingID  DataYear                          BuildingName  \
# 258             390      2020                      LOWES & AMAZON W
# 728           19776      2020            AMAZON DISTRIBUTION CENTER
# 3257          49985      2020  AMAZON PHASE VI - NESSIE AND BIGFOOT
# 3300          50037      2020                  APOLLO BLDG (AMAZON)
# 3305          50045      2020                         AMAZON BRAZIL
# 3359          50160      2020               AMAZON DOPPLER BUILDING
# 3387          50192      2020                   MIDTOWN 21 (AMAZON)
# 3397          50241      2020                   TROY BLOCK (AMAZON)
# 3419          50270      2020     URBAN UNION (AMELIA- AMAZON BLDG)
# 3424          50294      2020      DAY 1 TOWER AND SPHERES (Amazon)
# 3574          50528      2020                       AMAZON- UNICORN
# 3596          50656      2020  AMAZON REINVENT TOWERS (EAST + WEST)
#
#         BuildingType TaxParcelIdentificationNumber             Address  \
# 258   NonResidential                    0003600052  2700 RAINIER AVE S
# 728   NonResidential                    0164000020  13537 AURORA AVE N
# 3257  NonResidential                    1983200075       500 9TH AVE N
# 3300  NonResidential                    1991201265       325 9TH AVE N
# 3305  NonResidential                    1983200035       400 9TH AVE N
# 3359  NonResidential                    0659000775        2021 7TH AVE
# 3387  NonResidential                    0660001605    1007  STEWART ST
# 3397  NonResidential                    8692000000     300 BOREN AVE N
# 3419  NonResidential                    1983200560  501 FAIRVIEW AVE N
# 3424  NonResidential                    0660000220        2101 7TH AVE
# 3574  NonResidential                    1986200115       234 9TH AVE N
# 3596  NonResidential                    0660000270        2100 7TH AVE
#
#          City State  ZipCode  Latitude  ...  Electricity(kWh) SteamUse(kBtu)  \
# 258   SEATTLE    WA  98144.0  47.57936  ...           2268500              0
# 728   SEATTLE    WA  98133.0  47.72782  ...            656107              0
# 3257  SEATTLE    WA  98109.0  47.62384  ...           4037111              0
# 3300  SEATTLE    WA  98109.0  47.62154  ...           2827600              0
# 3305  SEATTLE    WA  98109.0  47.62264  ...           3051112              0
# 3359  SEATTLE    WA      NaN  47.61523  ...          12682380              0
# 3387  SEATTLE    WA      NaN  47.61632  ...           5198792              0
# 3397  SEATTLE    WA  98109.0  47.62107  ...           9009065              0
# 3419  SEATTLE    WA  98109.0  47.62334  ...           2779352              0
# 3424  SEATTLE    WA  98121.0  47.61586  ...          13639170              0
# 3574  SEATTLE    WA  98109.0  47.62053  ...           1661159              0
# 3596  SEATTLE    WA  98121.0  47.61629  ...           9993618              0
#
#       NaturalGas(therms)  ComplianceStatus  ComplianceIssue  \
# 258                17515         Compliant         No Issue
# 728                    0         Compliant         No Issue
# 3257               17259         Compliant         No Issue
# 3300               18234         Compliant         No Issue
# 3305               13200         Compliant         No Issue
# 3359               47104         Compliant         No Issue
# 3387                7901         Compliant         No Issue
# 3397               28064         Compliant         No Issue
# 3419                2792         Compliant         No Issue
# 3424               61085         Compliant         No Issue
# 3574               17131         Compliant         No Issue
# 3596               50602         Compliant         No Issue
#
#       Electricity(kBtu)  NaturalGas(kBtu)  TotalGHGEmissions  \
# 258           7740122.0         1751457.0              134.2
# 728           2238638.0               0.0               11.9
# 3257         13774623.0         1725861.0              164.9
# 3300          9647771.0         1823426.0              148.1
# 3305         10410394.0         1319979.0              125.5
# 3359         43272281.0         4710401.0              480.3
# 3387         17738278.0          790106.0              136.3
# 3397         30738930.0         2806441.0              312.5
# 3419          9483149.0          279192.0               65.3
# 3424         46536848.0         6108492.0              571.9
# 3574          5667875.0         1713090.0              121.1
# 3596         34098225.0         5060223.0              450.1
#
#       GHGEmissionsIntensity                     geometry
# 258                     0.5  POINT (-122.29744 47.57936)
# 728                     0.4  POINT (-122.34536 47.72782)
# 3257                    0.4  POINT (-122.33941 47.62384)
# 3300                    0.5  POINT (-122.34015 47.62154)
# 3305                    0.4  POINT (-122.33940 47.62264)
# 3359                    0.4  POINT (-122.33835 47.61523)
# 3387                    0.4  POINT (-122.33304 47.61632)
# 3397                    0.4  POINT (-122.33553 47.62107)
# 3419                    0.2  POINT (-122.33457 47.62334)
# 3424                    0.5  POINT (-122.33937 47.61586)
# 3574                    0.6  POINT (-122.33941 47.62053)
# 3596                    0.4  POINT (-122.33902 47.61629)
#
# [12 rows x 43 columns]

# %%
print(df[df['EPAPropertyType']=="Office"]["GHGEmissionsIntensity"].mean())
print(amazon['GHGEmissionsIntensity'].mean())
# Out:
# 0.7288747346072186
# 0.42500000000000004

# %%
len(df["EPAPropertyType"].unique())
# Out:
# 66

# %% [markdown]
# Carbon footprint of amazon buildings (TotalGHGEmissions)
# Similar to
# Non-Refrigerated Warehouse                                     6598.3
# Retail Store                                                   4563.0
# ^ Sum of total ghge emissions across entire EPA building types.
# Ranks about 13 out of 66 EPA proprety types.

# %%
amazon['TotalGHGEmissions'].sum()
# Out:
# 2538.2000000000003

# %%
amazon_ids = [
589,
336,
433,
471,
50528,
337,
376,
597,
21447,
750,
49985,
50045,
50037,
21445,
751,
371,
50192,
388,
50240,
50270,
334,
481
]

# %%
amazon = pd.concat([df[df['OSEBuildingID'].isin(amazon_ids)], df[df['BuildingName'].str.contains('amazon', case=False)]])
amazon['TotalGHGEmissions'].sum()
# Out:
# 5260.300000000001

# %% [markdown]
# Sooo amazon might make up 1.3% of emissions as defined by the total emissions in this dataset?

# %%
amazon["TotalGHGEmissions"].sum() /  df["TotalGHGEmissions"].sum() * 100
# Out:
# 1.310218021793213
