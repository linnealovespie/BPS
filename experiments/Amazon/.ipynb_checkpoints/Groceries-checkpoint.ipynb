# %% [markdown]
# # The Power of Clean Electricity: Grocery Store Carbon Emissions in Seattle
#
# [[grocery stores are really bad for the planet, blah blah]] [[cite data]]

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import pandas_gbq

# %%
# Fetch data for all Seattle buildings > 40k sq ft

query = """
    SELECT *
    FROM `GHGE_buildings_data.building-benchmark`;
"""

all_buildings_dataframe = pandas_gbq.read_gbq(query, project_id='seattle-377109')
# Out:
# Downloading: 100%|███████████████████████████████████████████████████████████████████████████████████|

# %% [markdown]
# ## Find grocery stores

# %%
all_buildings_dataframe.head()
# Out:
#    OSEBuildingID TaxParcelIdentificationNumber  DataYear    BuildingType  \
# 0          50148                    7733600135      2020  NonResidential
# 1          50150                    1991200090      2020  NonResidential
# 2          50160                     659000775      2020  NonResidential
# 3          50166                    4083306985      2020  NonResidential
# 4          50192                     660001605      2020  NonResidential
#
#               BuildingName                  Owner  CouncilDistrictCode  \
# 0  RESIDENCE INN SEATTLE U           TMUD GSL LLC                    4
# 1              HYATT HOUSE         HH SEATTLE LLC                    1
# 2  AMAZON DOPPLER BUILDING  ACORN DEVELOPMENT LLC                    7
# 3     TABLEAU (NORTH EDGE)       BRE-BMR 34TH LLC                    1
# 4      MIDTOWN 21 (AMAZON)          MIDTOWN21 LLC                    1
#
#   Neighborhood Units  YearBuilt  ... SecondLargestPropertyUseType  \
# 0    NORTHEAST  None       2016  ...                      Parking
# 1   LAKE UNION  None       2016  ...                      Parking
# 2     DOWNTOWN  None       2016  ...                      Parking
# 3   LAKE UNION  None       2016  ...                      Parking
# 4     DOWNTOWN  None       2016  ...                      Parking
#
#   SecondLargestPropertyUseTypeGFA ThirdLargestPropertyUseType  \
# 0                           54695                        None
# 1                           28069                        None
# 2                          448625           Convention Center
# 3                          117684                  Restaurant
# 4                          110813                        None
#
#    ThirdLargestPropertyUseTypeGFA  Outlier  ComplianceIssue ComplianceStatus  \
# 0                            <NA>     None         No Issue        Compliant
# 1                            <NA>     None         No Issue        Compliant
# 2                           59672     None         No Issue        Compliant
# 3                            2839     None         No Issue        Compliant
# 4                            <NA>     None         No Issue        Compliant
#
#   Comments DefaultData  LegislationPropertyType
# 0     None        None                    Hotel
# 1     None        None                    Hotel
# 2     None        None                   Office
# 3     None        None                   Office
# 4     None        None                   Office
#
# [5 rows x 52 columns]

# %%
all_buildings_dataframe.columns
# Out:
# Index(['OSEBuildingID', 'TaxParcelIdentificationNumber', 'DataYear',
#        'BuildingType', 'BuildingName', 'Owner', 'CouncilDistrictCode',
#        'Neighborhood', 'Units', 'YearBuilt', 'Address', 'City', 'State',
#        'ZipCode', 'Latitude', 'Longitude', 'PrimaryPropertyType',
#        'ListOfAllPropertyUseTypes', 'EPAPropertyType',
#        'TotalGHGEmissions__metric_tons_', 'ENERGYSTARScore',
#        'YearsENERGYSTARCertified', 'SiteEUI_kBtu_sf_', 'SiteEUIWN_kBtu_sf_',
#        'SiteEnergyUse_kBtu_', 'SiteEnergyUseWN_kBtu_', 'SourceEUI_kBtu_sf_',
#        'SourceEUIWN_kBtu_sf_', 'GHGEmissionsIntensityKgSqFt',
#        'NaturalGas_kBtu_', 'NaturalGas_therms_', 'Electricity_kBtu_',
#        'Electricity_kWh_', 'SteamUse_kBtu_', 'OtherFuelUse_kBtu_',
#        'PropertyGFATotal', 'PropertyGFABuilding_s_', 'PropertyGFAParking',
#        'NumberofBuildings', 'NumberofFloors', 'LargestPropertyUseType',
#        'LargestPropertyUseTypeGFA', 'SecondLargestPropertyUseType',
#        'SecondLargestPropertyUseTypeGFA', 'ThirdLargestPropertyUseType',
#        'ThirdLargestPropertyUseTypeGFA', 'Outlier', 'ComplianceIssue',
#        'ComplianceStatus', 'Comments', 'DefaultData',
#        'LegislationPropertyType'],
#       dtype='object')

# %%
all_buildings_dataframe['EPAPropertyType'].unique()
# Out:
# array(['Hotel', 'Office', 'K-12 School', 'Retail Store', 'Medical Office',
#        'Other - Recreation', 'Multifamily HR (10+)',
#        'Multifamily LR (1-4)', 'Multifamily MR (5-9)',
#        'Supermarket/Grocery Store', 'Non-Refrigerated Warehouse',
#        'Hospital (General Medical & Surgical)', 'Other', 'Museum',
#        'Parking', 'Laboratory', 'Restaurant', 'Bank Branch',
#        'Other - Mall', 'Unclassified', 'Enclosed Mall', 'Police Station',
#        'Worship Facility', 'Convention Center', 'Mixed Use Property',
#        'Multifamily Housing', 'Social/Meeting Hall',
#        'Self-Storage Facility', 'Other/Specialty Hospital',
#        'Residence Hall/Dormitory',
#        'Other - Entertainment/Public Assembly',
#        'Outpatient Rehabilitation/Physical Therapy', 'College/University',
#        'Distribution Center', 'Residential Care Facility',
#        'Manufacturing/Industrial Plant', 'Library', 'Courthouse',
#        'Fire Station', 'Performing Arts', 'Prison/Incarceration',
#        'Other - Lodging/Residential', 'Fitness Center/Health Club/Gym',
#        'Transportation Terminal/Station',
#        'Convenience Store without Gas Station', 'Strip Mall',
#        'Data Center', 'Stadium (Open)', 'Adult Education',
#        'Repair Services (Vehicle, Shoe, Locksmith, etc)',
#        'Other - Utility', 'Other - Services', 'Refrigerated Warehouse',
#        'Pre-school/Daycare', 'Lifestyle Center', 'Energy/Power Station',
#        'Mailing Center/Post Office', 'Food Service',
#        'Urgent Care/Clinic/Other Outpatient', 'Other - Education',
#        'Automobile Dealership',
#        'Personal Services (Health/Beauty, Dry Cleaning, etc)',
#        'Movie Theater', 'Financial Office', 'Other - Public Services',
#        'Wholesale Club/Supercenter'], dtype=object)

# %%
potential_groceries = all_buildings_dataframe[all_buildings_dataframe['EPAPropertyType'].isin(['Supermarket/Grocery Store', 'Refrigerated Warehouse', 'Wholesale Club/Supercenter'])]

potential_groceries[['OSEBuildingID', 'BuildingName', 'EPAPropertyType', 'LargestPropertyUseType', 'LargestPropertyUseTypeGFA', 'SecondLargestPropertyUseType', 'SecondLargestPropertyUseTypeGFA']]
# Out:
#       OSEBuildingID                             BuildingName  \
# 51            50195                      TOTAL WINE AND MORE
# 637           26473                                    Q F C
# 1112          20045                    2746 NE 45TH ST - QFC
# 1113          21921                      SAFEWAY STORE # 488
# 1114          24493                      METROPOLITAN MARKET
# 1170          50415   PORT OF SEATTLE- TERMINAL 115 (CAMPUS)
# 1279          22230                       THE BALLARD MARKET
# 1280          22240                     SAFEWAY STORE # 1477
# 1281          49946                            QFC - Ballard
# 1362            599                    Uwajimaya (Seattle 5)
# 1363          21784                    GOLDEN GRAIN MACARONI
# 1364          24132                 820 SOUTH ADAMS BUILDING
# 1365          27561                       OVERSEAS CASING CO
# 1366          28029                         PLYMOUTH POULTRY
# 1739          20565                      SAFEWAY STORE # 368
# 1740          35392                        QFC at 500 MERCER
# 1815          25914                     SAFEWAY STORE # 1551
# 1959            132                         ROOSEVELT SQUARE
# 1960          24479                      SAFEWAY STORE # 423
# 1961          27378                    SAFEWAY  STORE # 1550
# 2062          26986              ADMIRAL METROPOLITAN MARKET
# 2063          49775                 SVF ADMIRAL SAFEWAY 2932
# 2093            732                     FRED MEYER GREENWOOD
# 2094          23228                     SAFEWAY STORE # 1143
# 2175            607                             SAFEWAY 1965
# 2176          22142                             SAFEWAY #219
# 2177          23716                      SAARS MARKET (2012)
# 2356            264                   TRIBECA CONDOS & STORE
# 2357            700                     WHOLE FOODS INTERBAY
# 2358          22479                               QFC MARKET
# 2359          49687                            SAFEWAY #1885
# 2815            867             HARVARD MARKET (QFC Portion)
# 2975            500                     FRED MEYER LAKE CITY
# 2976          27821    QUALITY FOOD CENTER (QFC) SUPERMARKET
# 2977          41928                      SAFEWAY STORE #1586
# 3043          20435                             TRADER JOE'S
# 3159            519                  SPROUTS FARMER'S MARKET
# 3160          24514             OAK TREE PLAZA - SUPERMARKET
# 3165            514                                    LOWES
# 3284            556  Charlie's Produce & Catering (Terminal)
# 3285          23971             Charlie's Produce & Catering
# 3286          24598              DISTRIBUTORS WAREHOUSING CO
# 3287          24716                       PACIFIC COMMERCIAL
# 3288          25275                            PLYMOUTH INC.
# 3290            464                         COSTCO 4TH AVE S
# 3291          24354                           1760 4TH AVE S
# 3389          27162                   WEST SEATTLE THRIFTWAY
# 3485          20520                           ORIENTAL MEATS
# 3488            802              QFC AND RITE AID DRUG STORE
# 3489          23098                 HILLTOP RED APPLE MARKET
# 3501            558                       QFC & DOLLAR STORE
# 3504            381                          QFC HOLMAN ROAD
#
#                  EPAPropertyType      LargestPropertyUseType  \
# 51     Supermarket/Grocery Store   Supermarket/Grocery Store
# 637    Supermarket/Grocery Store   Supermarket/Grocery Store
# 1112   Supermarket/Grocery Store   Supermarket/Grocery Store
# 1113   Supermarket/Grocery Store   Supermarket/Grocery Store
# 1114   Supermarket/Grocery Store   Supermarket/Grocery Store
# 1170      Refrigerated Warehouse      Refrigerated Warehouse
# 1279   Supermarket/Grocery Store   Supermarket/Grocery Store
# 1280   Supermarket/Grocery Store   Supermarket/Grocery Store
# 1281   Supermarket/Grocery Store   Supermarket/Grocery Store
# 1362      Refrigerated Warehouse      Refrigerated Warehouse
# 1363      Refrigerated Warehouse      Refrigerated Warehouse
# 1364      Refrigerated Warehouse      Refrigerated Warehouse
# 1365      Refrigerated Warehouse      Refrigerated Warehouse
# 1366      Refrigerated Warehouse      Refrigerated Warehouse
# 1739   Supermarket/Grocery Store   Supermarket/Grocery Store
# 1740   Supermarket/Grocery Store   Supermarket/Grocery Store
# 1815   Supermarket/Grocery Store   Supermarket/Grocery Store
# 1959   Supermarket/Grocery Store   Supermarket/Grocery Store
# 1960   Supermarket/Grocery Store   Supermarket/Grocery Store
# 1961   Supermarket/Grocery Store   Supermarket/Grocery Store
# 2062   Supermarket/Grocery Store   Supermarket/Grocery Store
# 2063   Supermarket/Grocery Store   Supermarket/Grocery Store
# 2093   Supermarket/Grocery Store   Supermarket/Grocery Store
# 2094   Supermarket/Grocery Store   Supermarket/Grocery Store
# 2175   Supermarket/Grocery Store   Supermarket/Grocery Store
# 2176   Supermarket/Grocery Store   Supermarket/Grocery Store
# 2177   Supermarket/Grocery Store   Supermarket/Grocery Store
# 2356   Supermarket/Grocery Store   Supermarket/Grocery Store
# 2357   Supermarket/Grocery Store   Supermarket/Grocery Store
# 2358   Supermarket/Grocery Store   Supermarket/Grocery Store
# 2359   Supermarket/Grocery Store   Supermarket/Grocery Store
# 2815   Supermarket/Grocery Store   Supermarket/Grocery Store
# 2975   Supermarket/Grocery Store   Supermarket/Grocery Store
# 2976   Supermarket/Grocery Store   Supermarket/Grocery Store
# 2977   Supermarket/Grocery Store   Supermarket/Grocery Store
# 3043   Supermarket/Grocery Store   Supermarket/Grocery Store
# 3159   Supermarket/Grocery Store   Supermarket/Grocery Store
# 3160   Supermarket/Grocery Store   Supermarket/Grocery Store
# 3165  Wholesale Club/Supercenter  Wholesale Club/Supercenter
# 3284      Refrigerated Warehouse      Refrigerated Warehouse
# 3285      Refrigerated Warehouse      Refrigerated Warehouse
# 3286      Refrigerated Warehouse      Refrigerated Warehouse
# 3287      Refrigerated Warehouse      Refrigerated Warehouse
# 3288      Refrigerated Warehouse      Refrigerated Warehouse
# 3290   Supermarket/Grocery Store   Supermarket/Grocery Store
# 3291   Supermarket/Grocery Store   Supermarket/Grocery Store
# 3389   Supermarket/Grocery Store   Supermarket/Grocery Store
# 3485      Refrigerated Warehouse      Refrigerated Warehouse
# 3488   Supermarket/Grocery Store   Supermarket/Grocery Store
# 3489   Supermarket/Grocery Store   Supermarket/Grocery Store
# 3501   Supermarket/Grocery Store   Supermarket/Grocery Store
# 3504   Supermarket/Grocery Store   Supermarket/Grocery Store
#
#       LargestPropertyUseTypeGFA SecondLargestPropertyUseType  \
# 51                        25763                         None
# 637                       31174                         None
# 1112                      96218                         None
# 1113                      34982                      Parking
# 1114                      24377                         None
# 1170                     358706   Non-Refrigerated Warehouse
# 1279                      29214                         None
# 1280                      47034                      Parking
# 1281                      41198                         None
# 1362                      76354                         None
# 1363                      45594                      Parking
# 1364                      25331                         None
# 1365                      13349   Non-Refrigerated Warehouse
# 1366                      46342                         None
# 1739                      25883                      Parking
# 1740                      45980                         None
# 1815                      44739                      Parking
# 1959                     129387                      Parking
# 1960                      35042                      Parking
# 1961                      41447                      Parking
# 2062                      30899                       Office
# 2063                      60876                 Retail Store
# 2093                     168735                      Parking
# 2094                      45522                      Parking
# 2175                      54434                      Parking
# 2176                      25946                      Parking
# 2177                      42760                         None
# 2356                      76268          Multifamily Housing
# 2357                      40928                 Retail Store
# 2358                      25987                         None
# 2359                      33997                      Parking
# 2815                      46984                         None
# 2975                     121087                      Parking
# 2976                      46978                         None
# 2977                      51841                      Parking
# 3043                      25762                         None
# 3159                      27999                 Retail Store
# 3160                      45155                         None
# 3165                     107931                      Parking
# 3284                     104099                         None
# 3285                      23419                       Office
# 3286                      21870                         None
# 3287                      15667                        Other
# 3288                      22000                        Other
# 3290                     158415                         None
# 3291                      23792                         None
# 3389                      31746                         None
# 3485                      25480                         None
# 3488                      28704                 Retail Store
# 3489                      21603                         None
# 3501                      44431                         None
# 3504                      61666                         None
#
#       SecondLargestPropertyUseTypeGFA
# 51                               <NA>
# 637                              <NA>
# 1112                             <NA>
# 1113                                0
# 1114                             <NA>
# 1170                            49885
# 1279                             <NA>
# 1280                                0
# 1281                             <NA>
# 1362                             <NA>
# 1363                                0
# 1364                             <NA>
# 1365                             8228
# 1366                             <NA>
# 1739                                0
# 1740                             <NA>
# 1815                                0
# 1959                                0
# 1960                                0
# 1961                                0
# 2062                              942
# 2063                             7116
# 2093                                0
# 2094                                0
# 2175                                0
# 2176                                0
# 2177                             <NA>
# 2356                            72564
# 2357                            14334
# 2358                             <NA>
# 2359                            30000
# 2815                             <NA>
# 2975                                0
# 2976                             <NA>
# 2977                                0
# 3043                             <NA>
# 3159                            22143
# 3160                             <NA>
# 3165                                0
# 3284                             <NA>
# 3285                             2266
# 3286                             <NA>
# 3287                             8690
# 3288                             2700
# 3290                             <NA>
# 3291                             <NA>
# 3389                             <NA>
# 3485                             <NA>
# 3488                            22081
# 3489                             <NA>
# 3501                             <NA>
# 3504                             <NA>

# %%
# None of the refridgerated warehouses are grocery stores, so we'll remove them.
potential_groceries = potential_groceries[potential_groceries['EPAPropertyType'] != 'Refrigerated Warehouse']

# Lowe's is a hardware store, not a grocery. Let's remove it.
potential_groceries = potential_groceries[potential_groceries['OSEBuildingID'] != 514]

# %%
# Some of the grocery stores have secondary uses (retail store, parking)
# Because the data doesn't distinguish emissions from different parts of a building, we will restrict to single-use buildings

potential_groceries['SecondLargestPropertyUseTypeGFA'] = potential_groceries['SecondLargestPropertyUseTypeGFA'].fillna(0)

single_use_grocery_stores = potential_groceries[potential_groceries['SecondLargestPropertyUseTypeGFA'] == 0]

single_use_grocery_stores.head()
# Out:
#       OSEBuildingID TaxParcelIdentificationNumber  DataYear    BuildingType  \
# 51            50195                    2771600911      2020  NonResidential
# 637           26473                    4083802815      2020  NonResidential
# 1112          20045                     925049330      2020  NonResidential
# 1113          21921                    2437200030      2020  NonResidential
# 1114          24493                    7974700270      2020  NonResidential
#
#                BuildingName                      Owner  CouncilDistrictCode  \
# 51      TOTAL WINE AND MORE            1550 ARMORY LLC                    1
# 637                   Q F C  DAMBROSIO ENTERPRISES LLC                    1
# 1112  2746 NE 45TH ST - QFC   QUALITY FOOD CENTERS INC                    1
# 1113    SAFEWAY STORE # 488                SAFEWAY INC                    4
# 1114    METROPOLITAN MARKET             PAJIS WA L L C                    4
#
#                Neighborhood      Units  YearBuilt  ...  \
# 51    MAGNOLIA / QUEEN ANNE       None       2016  ...
# 637              LAKE UNION  NOT_FOUND       1957  ...
# 1112              NORTHEAST  NOT_FOUND       1955  ...
# 1113              NORTHEAST  NOT_FOUND       1975  ...
# 1114              NORTHEAST  NOT_FOUND       1973  ...
#
#      SecondLargestPropertyUseType SecondLargestPropertyUseTypeGFA  \
# 51                           None                               0
# 637                          None                               0
# 1112                         None                               0
# 1113                      Parking                               0
# 1114                         None                               0
#
#      ThirdLargestPropertyUseType  ThirdLargestPropertyUseTypeGFA  Outlier  \
# 51                          None                            <NA>     None
# 637                         None                            <NA>     None
# 1112                        None                            <NA>     None
# 1113                        None                            <NA>     None
# 1114                        None                            <NA>     None
#
#       ComplianceIssue ComplianceStatus Comments DefaultData  \
# 51           No Issue        Compliant     None        None
# 637          No Issue        Compliant     None        None
# 1112         No Issue        Compliant     None        None
# 1113         No Issue        Compliant     None        None
# 1114         No Issue        Compliant     None        None
#
#         LegislationPropertyType
# 51    Supermarket/Grocery Store
# 637   Supermarket/Grocery Store
# 1112      Self-Storage Facility
# 1113  Supermarket/Grocery Store
# 1114  Supermarket/Grocery Store
#
# [5 rows x 52 columns]

# %%
seattle_grocery_stores_env_impact = single_use_grocery_stores[['OSEBuildingID', 'BuildingName', 'PropertyGFABuilding_s_', 'TotalGHGEmissions__metric_tons_', 'GHGEmissionsIntensityKgSqFt', 'Electricity_kWh_', 'Electricity_kBtu_', 'NaturalGas_kBtu_', 'NaturalGas_therms_', 'SteamUse_kBtu_', 'OtherFuelUse_kBtu_']]

seattle_grocery_stores_env_impact.sort_values('TotalGHGEmissions__metric_tons_', ascending=False)[:10]
# Out:
#       OSEBuildingID           BuildingName  PropertyGFABuilding_s_  \
# 3290            464       COSTCO 4TH AVE S                  158415
# 2975            500   FRED MEYER LAKE CITY                  121087
# 1280          22240   SAFEWAY STORE # 1477                   46068
# 1815          25914   SAFEWAY STORE # 1551                   44739
# 2093            732   FRED MEYER GREENWOOD                  118133
# 2175            607           SAFEWAY 1965                   61053
# 1961          27378  SAFEWAY  STORE # 1550                   38000
# 2977          41928    SAFEWAY STORE #1586                   51400
# 1114          24493    METROPOLITAN MARKET                   24377
# 1112          20045  2746 NE 45TH ST - QFC                   77424
#
#       TotalGHGEmissions__metric_tons_  GHGEmissionsIntensityKgSqFt  \
# 3290                            529.0                          3.3
# 2975                            423.0                          3.5
# 1280                            405.3                          8.8
# 1815                            375.0                          8.4
# 2093                            365.2                          3.1
# 2175                            354.9                          5.8
# 1961                            341.4                          9.0
# 2977                            325.3                          6.3
# 1114                            321.1                         13.2
# 1112                            306.7                          4.0
#
#       Electricity_kWh_  Electricity_kBtu_  NaturalGas_kBtu_  \
# 3290           4078974           13917459           8567611
# 2975           2544354            8681336           7096095
# 1280           1943709            6631935           6968000
# 1815           2701494            9217498           6138700
# 2093           3293683           11238046           5750448
# 2175           2256600            7699519           5912008
# 1961           1970443            6723152           5755700
# 2977           1677700            5724312           5551192
# 1114           1383365            4720041           5572911
# 1112           2547445            8691882           4904319
#
#       NaturalGas_therms_  SteamUse_kBtu_ OtherFuelUse_kBtu_
# 3290               85676               0               None
# 2975               70961               0               None
# 1280               69680               0               None
# 1815               61387               0               None
# 2093               57504               0               None
# 2175               59120               0               None
# 1961               57557               0               None
# 2977               55512               0               None
# 1114               55729               0               None
# 1112               49043               0               None

# %% [markdown]
# The [average US grocery store](https://www.epa.gov/sites/default/files/documents/gc_averagestoreprofile_final_june_2011_revised_1.pdf) is 46,000 sq ft and produces 1,383 metric tons of greenhouse gas a year.

# %%
avg_grocery_size = 46000.0
avg_grocery_ghge = 1383.0
avg_grocery_emissions_intensity_kg_sqft = (avg_grocery_ghge / avg_grocery_size) * 1000

print('Average US grocery store emissions intensity (kg/sq ft):')
print(round(avg_grocery_emissions_intensity_kg_sqft, 2))
# Out:
# Average US grocery store emissions intensity (kg/sq ft):
# 30.07

# %%
sns.boxplot(x=seattle_grocery_stores_env_impact['TotalGHGEmissions__metric_tons_'])
plt.axvline(x=avg_grocery_ghge)
plt.title('Total Greenhouse Gas Emissions from Large Grocery Stores in Seattle')
plt.show()

### label the mean?? and the quartiles??

# %%
sns.boxplot(x=seattle_grocery_stores_env_impact['GHGEmissionsIntensityKgSqFt'], color='magenta')
plt.axvline(x=30.07)
plt.title('Greenhouse Gas Emissions Intensity from Large Grocery Stores in Seattle')
plt.show()

# %%
seattle_avg_grocery_emissions_intensity_kg_sqft = np.mean(seattle_grocery_stores_env_impact['GHGEmissionsIntensityKgSqFt'])

### make this rounded
print(f'The average US grocery store has a greenhouse gas emissions intensity of {round(avg_grocery_emissions_intensity_kg_sqft, 2)} kg/sq ft per year.')

print(f'That is {round(avg_grocery_emissions_intensity_kg_sqft / seattle_avg_grocery_emissions_intensity_kg_sqft, 2)} times the Seattle average of {round(seattle_avg_grocery_emissions_intensity_kg_sqft, 2)} kg/sq ft per year.')
# Out:
# The average US grocery store has a greenhouse gas emissions intensity of 30.07 kg/sq ft per year.
# That is 6.16 times the Seattle average of 4.88 kg/sq ft per year.

# %% [markdown]
# On average, Seattle's grocery stores are producing about a sixth of the greenhouse gas emissions of a typical US grocery store.
#
# ## What makes Seattle's grocery stores cleaner than other stores?
#
# What is the total GHGE from Seattle's grocery stores?

# %%
total_seattle_grocery_ghge = seattle_grocery_stores_env_impact['TotalGHGEmissions__metric_tons_'].sum()

print(f'Seattle grocery stores produce {round(total_seattle_grocery_ghge, 1)} metric tons of greenhouse gas emissions each year.')
# Out:
# Seattle grocery stores produce 6807.9 metric tons of greenhouse gas emissions each year.

# %% [markdown]
# Now let's find out where Seattle's grocery stores' emissions come from.

# %%
seattle_grocery_energy_sources = pd.DataFrame(data={
    'electric_kbtu': [seattle_grocery_stores_env_impact['Electricity_kBtu_'].sum()],
    'gas_kbtu': [seattle_grocery_stores_env_impact['NaturalGas_kBtu_'].sum()],
    'steam_kbtu': [seattle_grocery_stores_env_impact['SteamUse_kBtu_'].sum()],
    'other_kbtu': [seattle_grocery_stores_env_impact['OtherFuelUse_kBtu_'].sum()]
})
seattle_grocery_energy_sources
# Out:
#    electric_kbtu     gas_kbtu  steam_kbtu  other_kbtu
# 0    181882719.0  109977944.0           0         0.0

# %% [markdown]
# Seattle's groceries use only electric and gas power. So we can discount steam and miscellaneous power sources as sources of emissions.

# %% [markdown]
# ### What is the average emission factor from electric power in the data?
#
# Let's see if we can calculate the emissions from Seattle City light by using the city's own emissions data.
#
# Process:
# 1. Find any and all electric-only buildings in the GHGE dataset.
# 1. Calculate metric CO2/kWh with this data and then take the average.

# %%
electric_only_buildings = all_buildings_dataframe.query('NaturalGas_kBtu_ == 0 & SteamUse_kBtu_ == 0 & OtherFuelUse_kBtu_ == 0')

electric_only_buildings[['TotalGHGEmissions__metric_tons_', 'Electricity_kWh_']].head()
# Out:
#     TotalGHGEmissions__metric_tons_  Electricity_kWh_
# 8                              14.5            798732
# 9                               7.9            433032
# 10                              2.6            142774
# 15                              3.8            211756
# 16                              3.6            199573

# %%
electric_only_buildings['electric_co2_m3_kwh'] = electric_only_buildings['TotalGHGEmissions__metric_tons_'] / electric_only_buildings['Electricity_kWh_']
# Out:
# /var/folders/dv/sn1_d0xn0vncjbncdpkkg_pc0000gn/T/ipykernel_55810/1019057827.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   electric_only_buildings['electric_co2_m3_kwh'] = electric_only_buildings['TotalGHGEmissions__metric_tons_'] / electric_only_buildings['Electricity_kWh_']

# %%
electric_only_buildings['electric_co2_m3_kwh'] = electric_only_buildings['electric_co2_m3_kwh'].astype(np.float64)
# Out:
# /var/folders/dv/sn1_d0xn0vncjbncdpkkg_pc0000gn/T/ipykernel_55810/3179569723.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   electric_only_buildings['electric_co2_m3_kwh'] = electric_only_buildings['electric_co2_m3_kwh'].astype(np.float64)

# %%
electric_only_buildings['electric_co2_m3_kwh'].describe()
# Out:
# count    1.177000e+03
# mean     1.813865e-05
# std      1.474555e-07
# min      1.654041e-05
# 25%      1.807664e-05
# 50%      1.814099e-05
# 75%      1.821060e-05
# max      1.910260e-05
# Name: electric_co2_m3_kwh, dtype: float64

# %%
sns.boxplot(x=electric_only_buildings['electric_co2_m3_kwh'])
plt.title('GHGE Intensity for Electric-only Buildings in Seattle')
plt.show()

# %% [markdown]
# So something is off with the data.
#
# Looking at the histogram, we see there are a lot of outlier data points. Electricity-produced GHGE should be the same for every building. This is because the dataset measures based on the number of kWh used by reading the meter, without consideration to the building's efficiency. (Any building-specific energy efficient factors would appear in this data set as reduced power use.)
#
# Let's see what happens when we use the official emissions factors.

# %% [markdown]
# ### Seattle Grocery Store Emissions
#
# From the [summary report](https://www.seattle.gov/documents/Departments/OSE/Seattle%20Energy%20Benchmarking%20Analysis%202016%20for%20web.pdf), the emissions factors for each type of power are:
#
# - Seattle City Light: 20.08 lbs. CO2/MWh
# - Steam from Enwave: 170.17 lbs. CO2/MBtu
# - Gas from Portfolio Manager: 53.11 kg CO2/MBtu
#
# Convert these factors to metric tons per KWh and kBtu:

# %%
city_light_factor_lbs_mwh = 20.08
city_light_factor_tons_mwh = city_light_factor_lbs_mwh / 2204.62
city_light_factor_tons_kwh = city_light_factor_tons_mwh / 1000

city_light_factor_tons_kwh
# Out:
# 9.108145621467645e-06

# %%
gas_factor_kg_mbtu = 53.11
gas_factor_tons_mbtu = gas_factor_kg_mbtu / 1000
gas_factor_tons_kbtu = gas_factor_tons_mbtu / 1000

gas_factor_tons_kbtu
# Out:
# 5.311e-05

# %%
total_seattle_grocery_ghge = seattle_grocery_stores_env_impact['TotalGHGEmissions__metric_tons_'].sum()

total_seattle_grocery_ghge
# Out:
# 6807.900000000001

# %%
electric_impact_est = seattle_grocery_stores_env_impact['Electricity_kWh_'].sum() * city_light_factor_tons_kwh
electric_impact_est
# Out:
# 485.52587841895655

# %%
gas_impact_est = seattle_grocery_stores_env_impact['NaturalGas_kBtu_'].sum() * gas_factor_tons_kbtu
gas_impact_est
# Out:
# 5840.928605839999

# %%
print('Gap between estimate and actual emissions (metric tons):')
total_seattle_grocery_ghge - electric_impact_est - gas_impact_est
# Out:
# Gap between estimate and actual emissions (metric tons):
# 481.4455157410448

# %% [markdown]
# ## How much is each grocery store off?
#
# If this is a rounding error, we would expect each store to be off by the same amount.
#
# Method:
# 1. Estimate the expected GHGE based on the emissions factors provided in the city's report (see above).
# 2. Calculate the difference between the estimated and actual emissions.

# %%
seattle_grocery_stores_env_impact['estimated_ghge'] = (seattle_grocery_stores_env_impact['Electricity_kWh_'] * city_light_factor_tons_kwh) + (seattle_grocery_stores_env_impact['NaturalGas_kBtu_'] * gas_factor_tons_kbtu)
seattle_grocery_stores_env_impact['percent_diff_estimated_real_ghge'] = (seattle_grocery_stores_env_impact['TotalGHGEmissions__metric_tons_'] - seattle_grocery_stores_env_impact['estimated_ghge']) / seattle_grocery_stores_env_impact['TotalGHGEmissions__metric_tons_']

# %%
sns.boxplot(x=seattle_grocery_stores_env_impact['percent_diff_estimated_real_ghge'])
plt.title('Difference between actual and expected GHGE for grocery stores')
plt.show()

# %%
seattle_grocery_stores_env_impact['percent_diff_estimated_real_ghge'].describe()
# Out:
# count    31.000000
# mean      0.132923
# std       0.149466
# min       0.039000
# 25%       0.054714
# 50%       0.069303
# 75%       0.094124
# max       0.498366
# Name: percent_diff_estimated_real_ghge, dtype: float64

# %% [markdown]
# ## OK, what's going on?
#
# Options:
# - Reread report on how this data is collected
# - What is the error from rounding?
