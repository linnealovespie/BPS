# %%
import numpy as np
import pandas as pd
import pandas_gbq

# %%
from bokeh.palettes import Category20c
from bokeh.plotting import figure, show, output_notebook
from bokeh.transform import cumsum
from bokeh.resources import INLINE
import bokeh.io

# %%
query = """
    SELECT *
    FROM `GHGE_buildings_data.building-benchmark`;
"""

buildings_dataframe = pandas_gbq.read_gbq(query, project_id='seattle-377109')
# Out:
# Downloading: 100%|███████████████████████████████████████████████████████████████████████████████████|

# %%
age_v_efficiency_redo = figure(width=400, height=400)

# add a circle renderer with a size, color, and alpha
age_v_efficiency_redo.circle(list(buildings_dataframe['YearBuilt']), list(buildings_dataframe['GHGEmissionsIntensity']))
# Out:
# GlyphRenderer(id='p1053', ...)

# %%
output_notebook()
show(age_v_efficiency_redo)
# Out:
# <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="p1060">Loading BokehJS ...</span>
#     </div>
#   <div id="e8b8fd9e-d6ea-43cd-9030-d9910c2faa46" data-root-id="p1001" style="display: contents;"></div>

# %%
redo = figure(width=400, height=400)

# add a circle renderer with a size, color, and alpha
redo.circle(list(buildings_dataframe['YearBuilt']), list(buildings_dataframe['GHGEmissionsIntensity']))

# %%
show(redo)

# %%
# x = np.array(buildings_dataframe['YearBuilt'])
# y = np.array(buildings_dataframe['GHGEmissionsIntensity'])

# best fit line
par = np.polyfit(buildings_dataframe['YearBuilt'], buildings_dataframe['GHGEmissionsIntensity'], 1, full=True)
slope = par[0][0]
intercept = par[0][1]
y_predicted = [slope*i + intercept  for i in x]

# plot it
best_fit_line = figure()
best_fit_line.circle(x,y)
best_fit_line.line(x,y_predicted,color='red')
show(best_fit_line)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [8], in <cell line: 5>()
#       1 # x = np.array(buildings_dataframe['YearBuilt'])
#       2 # y = np.array(buildings_dataframe['GHGEmissionsIntensity'])
#       3
#       4 # best fit line
# ----> 5 par = np.polyfit(buildings_dataframe['YearBuilt'], buildings_dataframe['GHGEmissionsIntensity'], 1, full=True)
#       6 slope = par[0][0]
#       7 intercept = par[0][1]
#
# File <__array_function__ internals>:180, in polyfit(*args, **kwargs)
#
# File /usr/local/lib/python3.9/site-packages/numpy/lib/polynomial.py:646, in polyfit(x, y, deg, rcond, full, w, cov)
#     644 # set rcond
#     645 if rcond is None:
# --> 646     rcond = len(x)*finfo(x.dtype).eps
#     648 # set up least squares equation for powers of x
#     649 lhs = vander(x, order)
#
# ...

# %%
years = list(buildings_dataframe['YearBuilt'])
intensity = list(buildings_dataframe['GHGEmissionsIntensity'])

# %%
years
# Out:
# [2016,
#  2016,
#  2016,
#  2016,
#  2016,
#  2016,
#  1970,
#  2016,
#  2016,
#  2016,
#  2005,
#  1912,
#  2016,
#  1970,
#  2016,
#  2016,
#  2016,
#  2016,
#  2016,
#  2016,
#  2016,
#  2016,
#  2017,
#  2016,
#  2015,
#  2016,
#  2017,
#  2016,
#  2016,
#  2016,
#  2016,
#  2016,
#  2016,
#  2016,
#  2016,
#  2017,
#  2016,
#  1970,
#  2015,
#  2017,
#  2016,
#  2016,
#  2017,
#  2016,
#  2015,
#  2016,
#  2017,
#  2017,
#  2017,
#  2018,
#  2017,
#  2016,
#  2017,
#  1960,
#  1927,
#  1996,
#  1969,
#  1926,
#  1926,
#  1969,
#  1998,
#  1980,
#  1922,
#  1991,
#  2001,
#  1900,
#  1930,
#  1982,
#  1985,
#  1908,
#  1999,
#  1923,
#  1930,
#  1973,
#  1926,
#  2015,
#  2018,
#  2017,
#  2018,
#  1955,
#  2004,
#  1991,
#  1973,
#  1910,
#  1989,
#  1976,
#  2000,
#  1926,
#  1930,
#  1916,
#  1969,
#  2009,
#  1990,
#  1968,
#  1991,
#  1958,
#  1980,
#  1972,
#  1980,
#  1988,
#  1927,
#  1964,
#  1960,
#  1976,
#  1988,
#  1989,
#  1958,
#  1914,
#  1921,
#  1983,
#  1926,
# ...

# %%
par_reg = np.polyfit(years, intensity, 1, full=True)
slope_reg = par_reg[0][0]
intercept_reg = par_reg[0][1]
y_predicted_reg = [slope_reg*i + intercept_reg for i in years]

# %%
reg_fig = figure()
reg_fig.circle(years, intensity)
reg_fig.line(years,y_predicted_reg,color='red')
show(reg_fig)
# Out:
#   <div id="5497dbd7-9a94-43c1-9cb5-c2bcf397ec56" data-root-id="p1575" style="display: contents;"></div>

# %%
y_predicted_reg
